# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Analysis of additionally gathered data
# Based on the data extracted from the first round I import the three spreadsheets and look at affiliations, justifications and diseases in turn in this notebook, gathering some numbers and insights for analysis

# %%
#reading in files
aff = pd.read_csv('affiliations_data.csv', sep = ';')
jus = pd.read_csv('justification_data.csv', sep = ';')
dis = pd.read_csv('disease_data.csv', sep = ';')

# %%
#filling in nan values with 0's for easier handling
aff = aff.fillna(0)
dis = dis.fillna(0)

# %%
#removing id columns for increased readability
aff.drop(["list of 2012 ids", "list of 2021 ids"], axis = 1, inplace = True)

# %%
#adding count
aff['count']=aff['Counter 2012'] + aff['Counter 2021']
aff = aff.sort_values(by=['count'], ascending = False)

# %% [markdown]
# ## Affiliations

# %%
#dictionary with country as key and categories as list items in value

def create_country_cat(df):
    dic = {}
    for index in range(len(df)):
        country = df.iloc[index, 3].strip()
        category = df.iloc[index, 2].strip()
        total_count = df.iloc[index, 5]
        count12 =df.iloc[index, 0]
        count21 = df.iloc[index, 1]
        if country not in dic:         
            dic[country] = [[category, total_count, count12, count21]] #add new empty list if country not in dic
        else: 
            dic[country].append([category, total_count, count12, count21])
    return dic

# %%
#[gov, uni, hosp, corp]
#count = 1 to get total count
#count = 2 to get 2012 count
#count = 3 to get 2021 count
def count_country_cat(dic, count):
    count_dic = {}
    for key in dic.keys():
        count_list = [0,0,0,0]
        for category in dic.get(key):
            #if the category name matches add the count to the appropriate list
            if category[0] == 'gov':
                count_list[0]+=category[count]
            
            elif category[0] == 'uni':
                count_list[1]+=category[count]
            
            elif category[0] == 'hosp':
                count_list[2]+=category[count]
            
            elif category[0] == 'corp':
                count_list[3]+=category[count]

            #making them percentages instead
            #total = sum(count_list)
            #if total != 0:
               # count_list[0] = count_list[0]/total*100
               # count_list[1] = count_list[1]/total*100
               # count_list[2] = count_list[2]/total*100
               # count_list[3] = count_list[3]/total*100
            
        count_dic[key] = count_list
    return count_dic

# %%
#count = 1 to get total count
#count = 2 to get 2012 count
#count = 3 to get 2021 count
#cut_off is for the threshold
def make_country_df(aff, count, cut_off):

    
    country_category = count_country_cat(create_country_cat(aff), count)
    df = pd.DataFrame.from_dict(country_category)
    row_names = {0:'Government', 1:'University', 2:'Hospital', 3: 'Corporation'}
    df.rename(index= row_names, inplace=True)
    df= df.transpose()
    
    
    #adding count
    df['count']=df.sum(axis = 1)
    df = df.sort_values(by=['count'], ascending = False)
    
    #adding threshold
    threshold = df[df['count']> cut_off]
    
    #adding max value
    #val = threshold.iloc[:, [0, 1, 2, 3]].idxmax(axis=1)
    #threshold['max'] = val
    
    
    sum_corp = threshold.iloc[:, 3].sum(axis = 0)
    
    return sum_corp, threshold

# %%
sum_corp12, df2012 = make_country_df(aff, 2, 0)
#38 positive hits in 2012
sum_corp21, df2021 = make_country_df(aff, 3, 0)
#73 positive hits in 2021

# %% [markdown]
# ## Finding elite universities

# %%
universities = aff[aff['Type']=='uni']
universities
# Out:
#      Counter 2012  Counter 2021 Type        Country  \
# 232           3.0           3.0  uni  United States
# 57            2.0           3.0  uni          China
# 233           4.0           1.0  uni  United States
# 195           2.0           3.0  uni  United States
# 28            0.0           5.0  uni          China
# ..            ...           ...  ...            ...
# 108           1.0           0.0  uni        Germany
# 109           0.0           1.0  uni        Germany
# 110           1.0           0.0  uni        Germany
# 111           0.0           1.0  uni         Greece
# 247           0.0           1.0  uni        Vietnam
#
#                                             Name  count
# 232  University of North Carolina at Chapel Hill    6.0
# 57                 Shanghai Jiao Tong University    5.0
# 233                   University of Pennsylvania    5.0
# 195                     Johns Hopkins University    5.0
# 28                   Chinese Academy of Sciences    5.0
# ..                                           ...    ...
# 108                        University of Luebeck    1.0
# 109                       University of Tubingen    1.0
# 110                      University of Wuppertal    1.0
# 111                       University of Thessaly    1.0
# 247                                VinUniversity    1.0
#
# [129 rows x 6 columns]

# %%
elite = pd.read_csv('elite_universities.csv', sep = ';')
elite = elite.iloc[0:50, :]

# %%
elite_dic = {}
for index in range(len(elite)):
    elite_dic[elite.iloc[index, 1].strip()] = [1, elite.iloc[index, 2]]

# %%
elite_list = []
for index in range(len(universities)):
    if universities.iloc[index, 4].strip() not in elite_dic:
        elite_list.append('non-elite')
    else:
        elite_list.append('elite')

# %%
universities['elite']= elite_list
# Out:
# C:\Users\chris\AppData\Local\Temp/ipykernel_9164/3733115321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   universities['elite']= elite_list

# %%
universities[universities['elite'] == 'elite']
# Out:
#      Counter 2012  Counter 2021 Type         Country  \
# 57            2.0           3.0  uni           China
# 233           4.0           1.0  uni   United States
# 195           2.0           3.0  uni   United States
# 226           3.0           0.0  uni   United States
# 71            0.0           3.0  uni   Hong Kong SAR
# 102           0.0           3.0  uni         Germany
# 174           2.0           1.0  uni  United Kingdom
# 113           0.0           3.0  uni   Hong Kong SAR
# 163           1.0           2.0  uni  United Kingdom
# 200           0.0           2.0  uni   United States
# 166           1.0           1.0  uni  United Kingdom
# 52            0.0           2.0  uni           China
# 221           1.0           1.0  uni   United States
# 229           1.0           1.0  uni   United States
# 170           0.0           1.0  uni  United Kingdom
# 149           0.0           1.0  uni     Switzerland
# 244           0.0           1.0  uni   United States
# 206           0.0           1.0  uni   United States
# 186           1.0           0.0  uni   United States
# 188           1.0           0.0  uni   United States
# 191           0.0           1.0  uni   United States
# 73            0.0           1.0  uni           China
# 77            0.0           1.0  uni           China
# 14            1.0           0.0  uni          Canada
# 3             1.0           0.0  uni       Australia
# 18            1.0           0.0  uni          Canada
# 19            0.0           1.0  uni          Canada
# 132           1.0           0.0  uni       Singapore
# 133           1.0           0.0  uni       Singapore
#
#                                                   Name  count  elite
# 57                       Shanghai Jiao Tong University    5.0  elite
# 233                         University of Pennsylvania    5.0  elite
# 195                           Johns Hopkins University    5.0  elite
# 226       University of California, Los Angeles (UCLA)    3.0  elite
# 71          The Chinese University of Hong Kong (CUHK)    3.0  elite
# 102                     Technical University of Munich    3.0  elite
# 174                               University of Oxford    3.0  elite
# 113                        The University of Hong Kong    3.0  elite
# 163                              King's College London    3.0  elite
# 200        Massachusetts Institute of Technology (MIT)    2.0  elite
# 166                            Imperial College London    2.0  elite
# 52                                   Peking University    2.0  elite
# 221                                Stanford University    2.0  elite
# 229           University of California, Berkeley (UCB)    2.0  elite
# 170                                                UCL    1.0  elite
# 149  ETH Zurich - Swiss Federal Institute of Techno...    1.0  elite
# 244                                    Yale University    1.0  elite
# 206                            Northwestern University    1.0  elite
# 186                                Columbia University    1.0  elite
# 188                                    Duke University    1.0  elite
# 191                                 Harvard University    1.0  elite
# 73                                 Tsinghua University    1.0  elite
# 77                                 Zhejiang University    1.0  elite
# 14                                   McGill University    1.0  elite
# 3                             The University of Sydney    1.0  elite
# 18                      University of British Columbia    1.0  elite
# 19                               University of Toronto    1.0  elite
# 132  Nanyang Technological University, Singapore (NTU)    1.0  elite
# 133             National University of Singapore (NUS)    1.0  elite

# %%
#dividing into 2012 and 2021 to see the split of elite vs non-elite universities funding
uni_part = universities[universities['Counter 2012'] > 0]
num_art = uni_part['count'].sum()
print('2012: ')
print('number of articles affiliated with universities: ', num_art)
print(num_art/len(aff[aff['Counter 2012']> 0]))
print(len(uni_part), 'universities in total')
print('elite: ', len(uni_part[uni_part['elite'] == 'elite']), ' non-elite: ', len(uni_part[uni_part['elite'] == 'non-elite']))

uni_part = universities[universities['Counter 2021'] > 0]
num_art = uni_part['count'].sum()
print('2021: ')
print('number of articles affiliated with universities: ', num_art)
print(num_art/len(aff[aff['Counter 2021']> 0]))
print(len(uni_part), 'universities in total')
print('elite: ', len(uni_part[uni_part['elite'] == 'elite']), ' non-elite: ', len(uni_part[uni_part['elite'] == 'non-elite']))
# Out:
# 2012:
# number of articles affiliated with universities:  84.0
# 0.9333333333333333
# 48 universities in total
# elite:  16  non-elite:  32
# 2021:
# number of articles affiliated with universities:  159.0
# 0.8932584269662921
# 94 universities in total
# elite:  21  non-elite:  73

# %%
16/48
# Out:
# 0.3333333333333333

# %%
21/94
# Out:
# 0.22340425531914893

# %% [markdown]
# ## Looking at corporations

# %%
corporations = aff[aff['Type']=='corp']
corporations
# Out:
#      Counter 2012  Counter 2021  Type         Country  \
# 192           1.0           2.0  corp   United States
# 37            0.0           3.0  corp           China
# 210           0.0           2.0  corp   United States
# 53            0.0           2.0  corp           China
# 134           1.0           1.0  corp       Singapore
# 154           0.0           2.0  corp          Taiwan
# 164           0.0           2.0  corp  United Kingdom
# 175           0.0           2.0  corp  United Kingdom
# 180           0.0           2.0  corp   United States
# 50            0.0           2.0  corp           China
# 31            0.0           2.0  corp           China
# 32            0.0           2.0  corp           China
# 242           0.0           1.0  corp   United States
# 167           1.0           0.0  corp  United Kingdom
# 243           0.0           1.0  corp   United States
# 147           0.0           1.0  corp          Sweden
# 246           0.0           1.0  corp         Vietnam
# 150           0.0           1.0  corp     Switzerland
# 151           0.0           1.0  corp     Switzerland
# 179           1.0           0.0  corp   United States
# 181           0.0           1.0  corp   United States
# 182           0.0           1.0  corp   United States
# 224           0.0           1.0  corp   United States
# 145           0.0           1.0  corp          Sweden
# 208           0.0           1.0  corp   United States
# 219           0.0           1.0  corp   United States
# 218           1.0           0.0  corp   United States
# 215           1.0           0.0  corp   United States
# 225           1.0           0.0  corp   United States
# 187           0.0           1.0  corp   United States
# 190           0.0           1.0  corp   United States
# 193           1.0           0.0  corp   United States
# 194           1.0           0.0  corp   United States
# 43            1.0           0.0  corp           China
# 46            0.0           1.0  corp           China
# 49            0.0           1.0  corp           China
# 60            0.0           1.0  corp           China
# 39            0.0           1.0  corp           China
# 68            0.0           1.0  corp           China
# 69            0.0           1.0  corp           China
# 8             1.0           0.0  corp         Belgium
# 13            1.0           0.0  corp          Canada
# 15            1.0           0.0  corp          Canada
# 86            0.0           1.0  corp          France
# 130           1.0           0.0  corp          Russia
# 131           1.0           0.0  corp       Singapore
# 135           1.0           0.0  corp       Singapore
# 87            0.0           1.0  corp          France
# 93            0.0           1.0  corp         Germany
# 95            0.0           1.0  corp         Germany
# 101           1.0           0.0  corp         Germany
# 104           0.0           1.0  corp         Germany
#
#                                                   Name  count
# 192                                               IBM     3.0
# 37                       Huawei Technologies Co., Ltd.    3.0
# 210                                           PAII Inc    2.0
# 53                                   PingAn Technology    2.0
# 134                               Singapore ASTAR SERC    2.0
# 154                                           aetherAI    2.0
# 164                                        Astrazeneca    2.0
# 175                                     Wellcome Trust    2.0
# 180                                            Amazon     2.0
# 50                                          Pazhou Lab    2.0
# 31                                       Alibaba Group    2.0
# 32                                     Deepwise AI Lab    2.0
# 242                                     VoxelCloud Inc    1.0
# 167         Microsoft Research, Cambridge, CB3 0FB, UK    1.0
# 243                                            Wistron    1.0
# 147                                          Sectra AB    1.0
# 246  Medical Imaging Center, Vingroup Big Data Inst...    1.0
# 150                           Helmut Horten Foundation    1.0
# 151                                        Novartis AG    1.0
# 179                                               ADNI    1.0
# 181                               Boehringer-Ingelheim    1.0
# 182                               Bristol Myers-Squibb    1.0
# 224                                   Tempus Labs, Inc    1.0
# 145               Knut and Alice Wallenberg Foundation    1.0
# 208                                 NVIDIA Corporation    1.0
# 219                             Skin Cancer Foundation    1.0
# 218  Siemens Corporation, Corporate Research and Te...    1.0
# 215  Research to Prevent Blindness, Inc. (New York,...    1.0
# 225        The Eye and Ear Foundation (Pittsburgh, PA)    1.0
# 187                             Dermatology Foundation    1.0
# 190                           Google Research Award 21    1.0
# 193  Intel Science and Technology Center on Embedde...    1.0
# 194          Intuitive Surgical, Inc, Sunnyvale CA USA    1.0
# 43                 Microsoft Research Asia, P.R. China    1.0
# 46                                    NEC Laboratories    1.0
# 49                                             Nullmax    1.0
# 60      Shanghai United Imaging Intelligence Co., Ltd.    1.0
# 39                             Imsight AI Research Lab    1.0
# 68                                      Tencent AI Lab    1.0
# 69                                  Tencent Jarvis Lab    1.0
# 8                        icoMetrix NV, Leuven, Belgium    1.0
# 13   Cancer Control Research Program, BC Cancer Res...    1.0
# 15                  NeuroRx Research, Montreal, Canada    1.0
# 86                                               GENCI    1.0
# 130                             Yandex, Moscow, Russia    1.0
# 131  Institute for Infocomm Research, Agency for Sc...    1.0
# 135        Singapore Eye Research Institute, Singapore    1.0
# 87                                       Telecom Paris    1.0
# 93             German Academic Exchange Service (DAAD)    1.0
# 95                                        Helmholtz AI    1.0
# 101  Siemens AG, Corporate Technology, Erlangen, Ge...    1.0
# 104                                 Tubingen AI Center    1.0

# %%
#dividing into 2012 and 2021 to see the split of corporation funding for all articles funded
uni_part = corporations[corporations['Counter 2012'] > 0]
num_art = uni_part['count'].sum()
print('2012: ', num_art,' funded by corporations, out of ' ,len(aff[aff['Counter 2012']> 0]), 'in total')
print(num_art/len(aff[aff['Counter 2012']> 0]))


uni_part = corporations[corporations['Counter 2021'] > 0]
num_art = uni_part['count'].sum()
print('2021: ', num_art,' funded by corporations, out of ', len(aff[aff['Counter 2021']> 0]) ,'in total')
print(num_art/len(aff[aff['Counter 2021']> 0]))
# Out:
# 2012:  20.0  funded by corporations, out of  90 in total
# 0.2222222222222222
# 2021:  51.0  funded by corporations, out of  178 in total
# 0.28651685393258425

# %% [markdown]
# ## Hopsitals and government affilitations in numbers

# %%
hospital = aff[aff['Type']=='hosp']
hospital
# Out:
#      Counter 2012  Counter 2021  Type         Country  \
# 177           2.0           0.0  hosp   United States
# 240           0.0           2.0  hosp   United States
# 169           1.0           0.0  hosp  United Kingdom
# 168           0.0           1.0  hosp  United Kingdom
# 162           1.0           0.0  hosp          Uganda
# 155           0.0           1.0  hosp          Taiwan
# 158           0.0           1.0  hosp          Taiwan
# 185           1.0           0.0  hosp   United States
# 203           0.0           1.0  hosp   United States
# 223           1.0           0.0  hosp   United States
# 220           1.0           0.0  hosp   United States
# 213           1.0           0.0  hosp   United States
# 217           1.0           0.0  hosp   United States
# 196           1.0           0.0  hosp   United States
# 197           0.0           1.0  hosp   United States
# 51            0.0           1.0  hosp           China
# 54            0.0           1.0  hosp           China
# 70            0.0           1.0  hosp           China
# 5             1.0           0.0  hosp         Austria
# 10            1.0           0.0  hosp         Belgium
# 16            0.0           1.0  hosp          Canada
# 17            0.0           1.0  hosp          Canada
# 21            1.0           0.0  hosp           China
# 27            0.0           1.0  hosp           China
# 84            0.0           1.0  hosp          France
# 120           0.0           1.0  hosp           Japan
# 123           1.0           0.0  hosp     Netherlands
# 97            1.0           0.0  hosp         Germany
# 105           1.0           0.0  hosp         Germany
# 106           1.0           0.0  hosp         Germany
#
#                                                   Name  count
# 177                 Childrens Hospital of Philadelphia    2.0
# 240               Vanderbilt University Medical Center    2.0
# 169  RCUK Centre for Doctoral Training in Healthcar...    1.0
# 168   National Hospital for Neurology and Neurosurgery    1.0
# 162                 Mulago Hospital of Kampala, Uganda    1.0
# 155                       Chang Gung Memorial Hospital    1.0
# 158                National Taiwan University Hospital    1.0
# 185  Children Hospital of L.A., Department of Patho...    1.0
# 203                  Newark Beth Israel Medical Center    1.0
# 223              Stony Brook University Medical Center    1.0
# 220              St. Jude Children’s Research Hospital    1.0
# 213                           Piedmont Heart Institute    1.0
# 217                     San Francisco General Hospital    1.0
# 196  Kaiser San Francisco Medical Center, San Franc...    1.0
# 197           Louis Stokes Cleveland VA Medical Center    1.0
# 51               Peking Union Medical College Hospital    1.0
# 54                                     Ruijin Hospital    1.0
# 70       The Affiliated Hospital of Qingdao University    1.0
# 5    St.Anna Childrens Hospital, Dept. Pediatrics M...    1.0
# 10   Medical Imaging Research Center, UZ Leuven, Be...    1.0
# 16            Pacific Centre for Reproductive Medicine    1.0
# 17                       Sunnybrook Research Institute    1.0
# 21              Beijing YouAn Hospital, Beijing, China    1.0
# 27                                   Changhai Hospital    1.0
# 84            Centre Hospitalier Universitaire de Lyon    1.0
# 120                    Kyoto Second Red Cross Hospital    1.0
# 123                     Atrium Medical Center, Heerlen    1.0
# 97   Institute of Neuroscience and Medicine (INM-1,...    1.0
# 105                       University Hospital Erlangen    1.0
# 106             University Hospital Schleswig-Holstein    1.0

# %%
#dividing into 2012 and 2021 to see the split of hospital funding for all articles funded
uni_part = hospital[hospital['Counter 2012'] > 0]
num_art = uni_part['count'].sum()
print('2012: ', num_art,' funded by hospitals, out of ' ,len(aff[aff['Counter 2012']> 0]), 'in total')
print(num_art/len(aff[aff['Counter 2012']> 0]))


uni_part = hospital[hospital['Counter 2021'] > 0]
num_art = uni_part['count'].sum()
print('2021: ', num_art,' funded by hospitals, out of ', len(aff[aff['Counter 2021']> 0]) ,'in total')
print(num_art/len(aff[aff['Counter 2021']> 0]))
# Out:
# 2012:  17.0  funded by hospitals, out of  90 in total
# 0.18888888888888888
# 2021:  15.0  funded by hospitals, out of  178 in total
# 0.08426966292134831

# %%
government = aff[aff['Type']=='gov']
government
# Out:
#      Counter 2012  Counter 2021 Type         Country  \
# 48            3.0          13.0  gov           China
# 204           7.0           7.0  gov   United States
# 207           2.0           3.0  gov   United States
# 45            0.0           5.0  gov           China
# 82            1.0           3.0  gov              EU
# 40            0.0           3.0  gov           China
# 58            0.0           3.0  gov           China
# 141           0.0           2.0  gov           Spain
# 171           0.0           2.0  gov  United Kingdom
# 94            0.0           2.0  gov         Germany
# 35            0.0           2.0  gov   Hong Kong SAR
# 23            0.0           2.0  gov           China
# 12            1.0           1.0  gov          Canada
# 237           0.0           1.0  gov   United States
# 238           0.0           1.0  gov   United States
# 148           0.0           1.0  gov          Sweden
# 157           0.0           1.0  gov          Taiwan
# 161           1.0           0.0  gov          Turkey
# 202           0.0           1.0  gov   United States
# 201           0.0           1.0  gov   United States
# 228           0.0           1.0  gov   United States
# 56            0.0           1.0  gov           China
# 59            0.0           1.0  gov           China
# 62            0.0           1.0  gov           China
# 67            0.0           1.0  gov           China
# 41            0.0           1.0  gov           China
# 142           1.0           0.0  gov           Spain
# 4             1.0           0.0  gov         Austria
# 9             1.0           0.0  gov         Belgium
# 33            0.0           1.0  gov           China
# 128           0.0           1.0  gov        Portugal
# 119           0.0           1.0  gov           Japan
# 125           0.0           1.0  gov     Netherlands
# 136           0.0           1.0  gov     South Korea
# 140           0.0           1.0  gov           Spain
# 91            0.0           1.0  gov         Germany
#
#                                                   Name  count
# 48   NSFC, National Natural Science Foundation of C...   16.0
# 204                                                NIH   14.0
# 207                                                NSF    5.0
# 45   National Key Research and Development Program ...    5.0
# 82                                 European Commission    4.0
# 40   Key-Area Research and Development Program of G...    3.0
# 58   Shanghai Municipal Science and Technology Majo...    3.0
# 141                        Spanish Ministry of Science    2.0
# 171                                             UK gov    2.0
# 94   German Ministry of Science and Education, Bava...    2.0
# 35            Hong Kong Innovation and Technology Fund    2.0
# 23                                         111 project    2.0
# 12   Canadian NSERC, CIHR-Skin Research\nTraining C...    2.0
# 237                                       US Air Force    1.0
# 238                US Department of Agriculture (USDA)    1.0
# 148                                         Sweden gov    1.0
# 157                 Ministry of Science and Technology    1.0
# 161                         TUBITAK-BIDEB 2219 program    1.0
# 202                        National Institute on Aging    1.0
# 201                National Institute of Mental Health    1.0
# 228                       U.S. Department of Education    1.0
# 56   Shandong Higher Education Young Science and Te...    1.0
# 59           Shanghai Science and Technology Committee    1.0
# 62   Shenzhen-Hong Kong Innovation Circle Category ...    1.0
# 67       Taishan Scholars Program of Shandong Province    1.0
# 41   LIST, Key Laboratory of Computer Network and I...    1.0
# 142  Talentia Fellowships Programme of the Andalusi...    1.0
# 4                                Austrian Science Fund    1.0
# 9    IWT - TBM project 070717 and Research Foundati...    1.0
# 33                                 Foundation of China    1.0
# 128                                        FCT project    1.0
# 119                                 JSPS KAKENHI, AMED    1.0
# 125                                       EFRO/OP-Oost    1.0
# 136                                   Korea government    1.0
# 140  Catalan Institution for Research and Advanced ...    1.0
# 91   Excellence Strategy of the German Federal and ...    1.0

# %%
#dividing into 2012 and 2021 to see the split of goverment funding for all articles funded
uni_part = government[government['Counter 2012'] > 0]
num_art = uni_part['count'].sum()
print('2012: ', num_art,' funded by governments, out of ' ,len(aff[aff['Counter 2012']> 0]), 'in total')
print(num_art/len(aff[aff['Counter 2012']> 0]))


uni_part = government[government['Counter 2021'] > 0]
num_art = uni_part['count'].sum()
print('2021: ', num_art,' funded by governments, out of ', len(aff[aff['Counter 2021']> 0]) ,'in total')
print(num_art/len(aff[aff['Counter 2021']> 0]))
# Out:
# 2012:  45.0  funded by governments, out of  90 in total
# 0.5
# 2021:  81.0  funded by governments, out of  178 in total
# 0.4550561797752809

# %% [markdown]
# ## Justification

# %%
def count_cat(df, year):
    df = df[df['year'] == year]
    dic = {}
    option_list= []
    for element in df.iloc[:, 1]:
        if "," in element:
            multiples = element.split(", ")
            for option in multiples:
                option_list.append(option)
        else:
            option_list.append(element)
    for option in option_list:
        if option not in dic:
            dic[option] = 1
        else:
            dic[option] = dic.get(option) + 1 
    return dic

# %%
cat2012 = count_cat(jus, 2012)
cat2021 = count_cat(jus, 2021)

# %%
for key in cat2012.keys():
    print(key)
    print(cat2012.get(key))
    print(cat2012.get(key)/38*100)
# Out:
# sci
# 25
# 65.78947368421053
# dis
# 12
# 31.57894736842105
# nov
# 9
# 23.684210526315788
# hc
# 7
# 18.421052631578945

# %%
for key in cat2021.keys():
    print(key)
    print(cat2021.get(key))
    print(cat2021.get(key)/73*100)
# Out:
# sci
# 55
# 75.34246575342466
# dis
# 26
# 35.61643835616438
# nov
# 17
# 23.28767123287671
# hc
# 22
# 30.136986301369863

# %% [markdown]
# ## Disease type/task/body part
# The findings in this section are written into a table in an appendix in my thesis

# %%
def count_column(df, column):
    dic = {}
    option_list= []
    for element in df.iloc[:, column]:
        if element != 0:
            option_list.append(element)
    for option in option_list:
        if option not in dic:
            dic[option] = 1
        else:
            dic[option] = dic.get(option) + 1 
    return dic

# %%
def option_per_zhou(df, year):
    df = df[df['year'] == year]
    zhou = count_column(df, 3)
    
    for key in zhou.keys():
        counter = zhou.get(key)
        cat = df[df['Zhou category'] == key]
        dis = count_column(cat, 1)
        task = count_column(cat, 4)
        res = dis | task #merging the two dictionaries
        zhou[key] = res
        zhou.get(key)['counter'] = counter
        
    return zhou

# %%
distribution2012 = option_per_zhou(dis, 2012)
distribution2021 = option_per_zhou(dis, 2021)

# %%
distribution2012
# Out:
# {'all': {'surgery': 1,
#   'detect regional differences in images for different diseases': 1,
#   'surgery robotic': 1,
#   'counter': 3},
#  'eyes': {'glaucoma ': 1,
#   'location of foveola for different diseases': 1,
#   'counter': 2},
#  'chest': {'cancer': 2, 'tuberculosis': 1, 'counter': 3},
#  'neuro': {'alzheimers': 3,
#   'cancer': 1,
#   'mild cognitive impairment': 1,
#   'autism': 2,
#   'multiple sclerosis': 1,
#   "parkinson's disease": 2,
#   'measuring nerve fibers': 1,
#   'population based pattern recognition brain in particular': 1,
#   'neonate brain mapping': 1,
#   'different applications': 1,
#   'counter': 14},
#  'microscopy': {'cancer': 2,
#   'metabolic response of cells': 1,
#   'cell death event detection': 1,
#   'cell feature analysis': 1,
#   'cell detection': 1,
#   'vesicle fusion/undocking': 1,
#   'phase contrast microscopy': 1,
#   'counter': 8},
#  'abdomen': {'cancer': 2, 'verebral body fractures': 1, 'counter': 3},
#  'cardiovascular': {'coronary artery disease': 2,
#   'capturing morphological changes over time': 1,
#   'counter': 3}}

# %%
distribution2021
# Out:
# {'eyes': {'gender prediction': 1,
#   'managing imbalanced datasets': 1,
#   'fixing overfitting models': 1,
#   'imbalanced datasets': 1,
#   'unsupervised anomoly detection': 1,
#   'counter': 5},
#  'neuro': {'alzheimers': 4,
#   'bipolar': 1,
#   'schizophrenia': 1,
#   'intercranial hemorrhage': 1,
#   'cancer': 4,
#   'autism': 1,
#   "parkinson's disease": 1,
#   'brain disease': 1,
#   'neurodegenerative disorders': 1,
#   'Subjective cognitive decline': 1,
#   'mild cognitive impairment': 1,
#   'major depression disorder': 1,
#   'brain midline delineation': 1,
#   'harmonization of medical data': 1,
#   'data labelling': 1,
#   'counter': 21},
#  'abdomen': {'cancer': 10,
#   'liver steatosis': 1,
#   "crohn's disease": 1,
#   'lumbar degeneration disease': 1,
#   'ulcerative colitis': 1,
#   'nonalcoholic fatty liver disease': 1,
#   'adolescent idopathic scoliosis': 1,
#   'gastrointestinal abnormalities': 1,
#   'embryo development stage detection': 1,
#   'evaluation of spinal bone lesions': 1,
#   'anatomy site recognition': 1,
#   'managing imbalanced datasets': 1,
#   'tumor classification': 1,
#   'histopathological image visual representation': 1,
#   'unsupervised anomoly detection': 1,
#   'counter': 24},
#  'chest': {'cancer': 6,
#   'covid': 3,
#   'pneumothorax': 1,
#   'lung disease': 1,
#   'pneumonia': 1,
#   'screening thoracic diseases': 1,
#   'alleviating data imbalance': 1,
#   'predicting survival time': 1,
#   'content based image retrieval for radiology': 1,
#   'mammography lesion matching': 1,
#   'labeling chest X-rays': 1,
#   'multi-view medical image analysis': 2,
#   'detecting pathologies and assesing pulmonary edema severity': 1,
#   'outlier detection': 1,
#   'preventing overfitting of models': 1,
#   'counter': 23},
#  'all': {'epilepsy': 1,
#   'cancer': 1,
#   'alleviating data imbalance': 1,
#   'predicting survival time': 1,
#   'universal lesion detection': 1,
#   'harmonization of medical data': 1,
#   'counter': 6},
#  'face': {'gender prediction': 1, 'counter': 1},
#  'microscopy': {'cancer': 3,
#   'alleviating data imbalance': 1,
#   'classifying rare diseases': 1,
#   'continual learning for intelligent diagnosis systems': 1,
#   'fixing overfitting models': 1,
#   'data labelling': 1,
#   'fixing degrading models (retrogress)': 1,
#   'imbalanced datasets': 1,
#   'preventing overfitting of models': 2,
#   'counter': 12},
#  'mouth': {'tooth localization': 1, 'counter': 1},
#  'thyroid': {'cancer': 1, 'counter': 1},
#  'cardiovascular': {'outlier detection': 1, 'counter': 1}}
