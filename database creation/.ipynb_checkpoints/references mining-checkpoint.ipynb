# %%
import pandas as pd
import re
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#reading in files
df_2012 = pd.read_csv('database_miccai_2012_with_cat.csv')
df_2021 = pd.read_csv('database_miccai_2021_with_cat.csv')

# %%
#removing unnecessary index column
df_2012 = df_2012.drop("Unnamed: 0", axis = 1)
df_2021 = df_2021.drop("Unnamed: 0", axis = 1)

# %%
df_2012.head()
# Out:
#                                                Title  \
# 0  Reliable Assessment of Perfusivity and Diffusi...
# 1  Multi-organ Abdominal CT Segmentation Using Hi...
# 2  Radiation-Free Drill Guidance in Interlocking ...
# 3  Developing Essential Rigid-Flexible Outer Shea...
# 4    Surgical Gesture Classification from Video Data
#
#                                              Authors Page numbers  \
# 0  M. Freiman, S. D. Voss, R. V. Mulkern, J. M. P...          1-9
# 1  Robin Wolz, Chengwen Chu, Kazunari Misawa, Ken...        10-17
# 2  Benoit Diotte, Pascal Fallavollita, Lejing Wan...        18-25
# 3  Siyang Zuo, Takeshi Ohdaira, Kenta Kuwana, Yos...        26-33
# 4     Benjamín Béjar Haro, Luca Zappella, René Vidal        34-41
#
#                                     DOI  Year of publication  \
# 0  /chapter/10.1007/978-3-642-33415-3_1               2012.0
# 1  /chapter/10.1007/978-3-642-33415-3_2               2012.0
# 2  /chapter/10.1007/978-3-642-33415-3_3               2012.0
# 3  /chapter/10.1007/978-3-642-33415-3_4               2012.0
# 4  /chapter/10.1007/978-3-642-33415-3_5               2012.0
#
#    Part of publication                  category
# 0                    1           category: other
# 1                    1           category: other
# 2                    1         category: unknown
# 3                    1         category: unknown
# 4                    1  category: classification

# %%
#finding the references
def find_reference(year, place):
    reference_list = []
    with open(place, "r", encoding = 'utf-8') as part:
        article = part.read()
        if year == 2012:
            references = [i.start() for i in re.finditer("References\n\n1", article)]
            other_ref = [i.start() for i in re.finditer("References\n\n\[1\]", article)]
            all_ref = references + other_ref
            all_ref.sort()
            
        if year == 2021:
            all_ref = [i.start() for i in re.finditer("References", article)]
        for index in all_ref: 
            reference_list.append(article[index:index+8000])

    return reference_list

# %%
#saving the references
ref_list2012 = find_reference(2012, r"C:\Users\chris\Desktop\Value-Analysis-Thesis\combining proceedings txt\miccai_2012_full_txt.txt")
ref_list2021 = find_reference(2021, r"C:\Users\chris\Desktop\Value-Analysis-Thesis\combining proceedings txt\miccai_2021_full_txt.txt")

# %%
def create_ref_dic(ref_list):
    year={}
    i=0
    for element in ref_list:
        year[i] = []
        references = [i.start() for i in re.finditer("\([0-9][0-9][0-9][0-9]\)", element)]
        for index in references:
            num = element[index+1:index+5]
            if int(num) > 1850 and int(num) < 2023: #eliminating some mistakes with numbers that are clearly not years
                # 1852 is the oldest one that is actually correct - get a few 10xx and 11xx errors in both
                year.get(i).append(num)
        i+=1
    return year

# %%
def add_references(df, ref_list_all):
    
    
    row_list = df[df['category'] == 'category: classification'].index
    df_class = df[df['category'] == 'category: classification']
    
    ref_dic = create_ref_dic(ref_list_all)
    
    oldest_list = []
    newest_list = []
    range_list = []
    class_dic = {}
    num_ref = []

    for element in row_list:
        ref_dic.get(element).sort()
        class_dic[element] = ref_dic.get(element) #need this otherwise the sort is forgotten
        ref_list = class_dic.get(element)
        oldest_list.append(int(ref_list[0]))
        newest_list.append(int(ref_list[len(ref_list)-1]))
        range_list.append(int(ref_list[len(ref_list)-1])- int(ref_list[0]))
        num_ref.append(len(ref_list))
   
    
    data = {'index': row_list,
            'Number of references': num_ref,
            'Oldest reference': oldest_list,
            'Newest reference' : newest_list,
            'Range of references': range_list
    } 
    
    ref = pd.DataFrame(data)
    
    df_class = df_class.reset_index()
    
    df_class = df_class.merge(ref, on = 'index')
 
    
    return df_class

# %%
df_2012class = add_references(df_2012, ref_list2012)

df_2021class = add_references(df_2021, ref_list2021)

# %% [markdown]
# Testing out analysis of references, first calculating the age of the references: subtract age of reference from citing papers year of publication, 2012 or 2021
#
# Not sure I'm going to need the add_references bit above.. eh

# %%
dic2012 = create_ref_dic(ref_list2012)
dic2021 = create_ref_dic(ref_list2021)

# %%
#method that updates the dictionary of index keys and ref list to contain tuples of ref year and age instead
#not used currently
def calc_age(dic, year):
    for key in dic.keys():
        ref_list = dic.get(key)
        with_age = []
        for ref in ref_list:
            with_age.append(year-int(ref))
        dic[key] = with_age
    return dic

# %%
#method that returns a single list of all the ages of the references in a given proceedings year
#only used currently for the below boxplot and double histogram
def age(dic, year):
    with_age = []
    for key in dic.keys():
        ref_list = dic.get(key)
        for ref in ref_list:
            age = year-int(ref)
            with_age.append(age)
    return with_age

# %%
#creating a boxplot, not very telling... could play around with the size perhaps?
plt.rcParams["figure.figsize"] = [5.50, 5.50]
plt.rcParams["figure.autolayout"] = True

data = {'2012': age(dic2012, 2012), '2021': age(dic2021, 2021)}
fig, ax = plt.subplots()

ax.boxplot(data.values())
ax.set_xticklabels(data.keys())

plt.show()

# %%
#creating two histograms - do want the y label to be on the far left side, but not shabby for now..
plt.rcParams["figure.figsize"] = [7.50, 5.50]
#plt.rcParams["figure.autolayout"] = True

data = {'2012': age(dic2012, 2012)}
data1 = {'2021': age(dic2021, 2021)}
fig, ((ax0, ax1)) = plt.subplots(nrows=1, ncols=2)

ax0.hist(data.values(), bins = 40)
ax0.set_title('2012')
ax0.set_xlabel('age in years')

ax1.hist(data1.values(), bins = 40)
ax1.set_title('2021')
#ax1.set_ylabel('number of references')

#fig, ax = plt.subplots()
#ax.hist(data.values(), bins = 40)


#plt.title('ages of references')
plt.xlabel('age in years')
plt.ylabel('number of references')
plt.show()

# %%
#creating a df mimicking the one from the acl paper to be able to use their code for figures/analysis
#adding venues to get the acl code to work, not used as all texts are from miccai
def create_df(df, year, ref_dic):
    
    paper_id = df[df['category'] == 'category: classification'].index
    
    list_of_id = []
    list_of_year = []
    list_of_cited_age = []
    venue = []
    i = 0
    for key in ref_dic.keys():
        ref_list = ref_dic.get(key)
        for ref in ref_list:
            list_of_id.append(paper_id[i])
            list_of_year.append(year)
            list_of_cited_age.append(year-int(ref))
            venue.append('miccai')
        if i < 89:
            i = i+1
        
    data = {'paper_id': list_of_id,
            'venue': venue,
           'year': list_of_year,
           'cited_age': list_of_cited_age}
    df = pd.DataFrame.from_dict(data)
    
    return df

# %%
df2012_with_year = create_df(df_2012, 2012, dic2012)
df2021_with_year = create_df(df_2021, 2021, dic2021)

df = pd.concat([df2012_with_year, df2021_with_year],    # Combine vertically
                          ignore_index = True,
                          sort = False)

#creating a df of paper id (for every row corresponding to citations), year of proceedings and cited age as columns

# %% [markdown]
# ## Code from here on down is mostly from acl repo!

# %%
#code from acl repo! 
# Count citations by year & cited_age
counts = df.groupby(['year', 'cited_age']).count()
counts = counts.reset_index().filter(items=['year', 'cited_age', 'venue'])
counts.columns.values[-1] = "count"


# Normalize by total no. of citations in year
nfactor = df.groupby(['year']).count().reset_index()
counts['count'] = counts['count'].astype(float)
counts['percent_of_citations'] = counts.apply(lambda x: 100 * x[2] / float(nfactor[nfactor['year']==x[0]]['paper_id']), axis=1)


sns.lineplot(data=counts, x='cited_age', y='percent_of_citations', hue='year', legend='full')
# Out:
# <AxesSubplot:xlabel='cited_age', ylabel='percent_of_citations'>

# %%
#looks very squished but works!
#acl code!
sns.set_context("paper", font_scale=1.5)
ax = sns.boxenplot(data=df, x='year', y='cited_age', palette=[sns.color_palette("Blues")[3]])

ax.set_xlabel("")
ax.set_ylabel("Age of citations")
plt.xticks(rotation=45)
# Out:
# (array([0, 1]), [Text(0, 0, '2012'), Text(1, 0, '2021')])

# %%
#acl code
# normalize by total no. of *papers* in year
pfactor = df['paper_id'].groupby(df['year']).nunique('paper_id').reset_index()
counts['count'] = counts['count'].astype(float)
pcounts = counts.apply(lambda x: [x[0], x[1], x[2] / float(pfactor[pfactor['year']==x[0]]['paper_id']), x[3]], axis=1, result_type='broadcast')

# cumulative count of citations of age X or older
# need to reverse first so we start from the oldest...
pcounts = pcounts.sort_values(by='cited_age', ascending=False)
# then cumulatively sum up, for each year individually
pcounts['cumcount'] = pcounts.groupby('year')['count'].transform(pd.Series.cumsum)

sns.lineplot(data=pcounts, x='cited_age', y='cumcount', hue='year', legend='full')
# Out:
# <AxesSubplot:xlabel='cited_age', ylabel='cumcount'>

# %% [markdown]
# The graph above shows the average number of citations per paper that are X or more years old. (copied from acl)

# %%
#acl code - can definitely see that that one paper from 1872(?) is insanely skewing things
#wait no, this makes no sense? Not sure this is correct at all?

#We can sanity-check that this calculation is correct by directly calculating the average number of citations per paper:

# no. of citations per paper
cpp = df.groupby(['paper_id', 'year']).count()['cited_age'].reset_index()
# mean by year
cpp.groupby('year').mean()
# Out:
#         paper_id   cited_age
# year
# 2012  125.922222   35.444444
# 2021  137.600000  146.044444

# %% [markdown]
# Tried the fancy one with stacked years, but didn't copy over and work... So will leave that work for later! - fig 4
# now for fig 8:
#
# Oldest citation per paper
# The following plot considers only the distribution of the oldest citation per publication:

# %%
#acl code
df_max = df.groupby(['paper_id', 'year'])["cited_age"].max().reset_index()
sns.set_context("paper", font_scale=1.5)
ax = sns.boxenplot(data=df_max, x='year', y='cited_age', palette=[sns.color_palette("Blues")[3]])

ax.set_xlabel("")
ax.set_ylabel("Age of citations")
plt.xticks(rotation=45)
# Out:
# (array([0, 1]), [Text(0, 0, '2012'), Text(1, 0, '2021')])

# %%
pd.set_option('display.max_rows', None)

# %%
#saving updated database to csv
df_2012class.to_csv("database_miccai_2012_with_ref.csv")
df_2021class.to_csv("database_miccai_2021_with_ref.csv")

# %%
df_2021class[df_2021class['Part of publication']==5]
# Out:
#      index                                              Title  \
# 94     255  CA-Net: Leveraging Contextual Features for Lun...
# 95     257  DAE-GCN: Identifying Disease-Related Features ...
# 96     258  Enhanced Breast Lesion Classification via Know...
# 97     259  Multiple Meta-model Quantifying for Medical Vi...
# 98     262  A Coherent Cooperative Learning Framework Base...
# 99     264  A Segmentation-Assisted Model for Universal Le...
# 100    265  Constrained Contrastive Distribution Learning ...
# 101    266  Conditional Training with Bounding Map for Uni...
# 102    267  Focusing on Clinically Interpretable Features:...
# 103    268  Categorical Relation-Preserving Contrastive Kn...
# 104    269  Tensor-Based Multi-index Representation Learni...
# 105    270  Region Ensemble Network for MCI Conversion Pre...
# 106    271  Airway Anomaly Detection by Prototype-Based Gr...
# 107    272  Energy-Based Supervised Hashing for Multimorbi...
# 108    273  Stochastic 4D Flow Vector-Field Signatures: A ...
# 109    275  ASC-Net: Adversarial-Based Selective Network f...
# 110    276  Cost-Sensitive Meta-learning for Progress Pred...
# 111    277  Effective Pancreatic Cancer Screening on Non-c...
# 112    278  Learning from Subjective Ratings Using Auto-De...
# 113    279  VertNet: Accurate Vertebra Localization and Id...
# 114    280  VinDr-SpineXR: A Deep Learning Framework for S...
# 115    281  Multi-frame Collaboration for Effective Endosc...
# 116    283  Balanced-MixUp for Highly Imbalanced Medical I...
# 117    284  Transfer Learning of Deep Spatiotemporal Netwo...
# 118    285  Retina-Match: Ipsilateral Mammography Lesion M...
# 119    286  Towards Robust Dual-View Transformation via De...
# 120    287  DeepOPG: Improving Orthopantomogram Finding Su...
# 121    288  Joint Spinal Centerline Extraction and Curvatu...
# 122    289  LDPolypVideo Benchmark: A Large-Scale Colonosc...
# 123    290  Continual Learning with Bayesian Model Based o...
# 124    291  Alleviating Data Imbalance Issue with Perturbe...
# 125    292  A Deep Reinforced Tree-Traversal Agent for Cor...
# 126    294  Predicting Symptoms from Multiphasic MRI via M...
# 127    295  Triplet-Branch Network with Prior-Knowledge Em...
# 128    297  Data Augmentation in Logit Space for Medical I...
# 129    298  Collaborative Image Synthesis and Disease Diag...
# 130    300  Meta-modulation Network for Domain Generalizat...
# 131    301  3D Brain Midline Delineation for Hematoma Pati...
# 132    302  Unsupervised Representation Learning Meets Pse...
# 133    304  Automating Embryo Development Stage Detection ...
# 134    306  Few Trust Data Guided Annotation Refinement fo...
# 135    307  Asymmetric 3D Context Fusion for Universal Les...
# 136    308  Detecting Outliers with Poisson Image Interpol...
# 137    309  MG-NET: Leveraging Pseudo-imaging for Multi-mo...
# 138    310  Multimodal Multitask Deep Learning for X-Ray I...
# 139    311  Linear Prediction Residual for Efficient Diagn...
# 140    312  Primary Tumor and Inter-Organ Augmentations fo...
# 141    313  Radiomics-Informed Deep Curriculum Learning fo...
# 142    314  Lung Cancer Risk Estimation with Incomplete Da...
# 143    315  Co-graph Attention Reasoning Based Imaging and...
# 144    316  Deep Orthogonal Fusion: Multimodal Prognostic ...
# 145    318  Combining 3D Image and Tabular Data via the Dy...
# 146    320  GKD: Semi-supervised Graph Knowledge Distillat...
# 147    321  Predicting Esophageal Fistula Risks Using a Mu...
# 148    322  Hybrid Aggregation Network for Survival Analys...
# 149    323  Intracerebral Haemorrhage Growth Prediction Ba...
# 150    324  AMINN: Autoencoder-Based Multiple Instance Neu...
# 151    325  Survival Prediction Based on Histopathology Im...
# 152    326  Beyond Non-maximum Suppression - Detecting Les...
# 153    327  A Structural Causal Model for MR Images of Mul...
# 154    328   $$\mathsf {EMA}$$ EMA : Auditing Data Removal...
# 155    329  AnaXNet: Anatomy Aware Multi-label Finding Cla...
# 156    330  Projection-Wise Disentangling for Fair and Int...
# 157    331  Attention-Based Multi-scale Gated Recurrent En...
#
#                                                Authors Page numbers  \
# 94   Mingzhou Liu, Fandong Zhang, Xinwei Sun, Yizho...        23-32
# 95   Churan Wang, Xinwei Sun, Fandong Zhang, Yizhou...        43-52
# 96   Kun Chen, Yuanfan Guo, Canqian Yang, Yi Xu, Ru...        53-63
# 97   Tuong Do, Binh X. Nguyen, Erman Tjiputra, Minh...        64-74
# 98   Xinxin Shan, Ying Wen, Qingli Li, Yue Lu, Haib...       96-106
# 99      Fei Lyu, Baoyao Yang, Andy J. Ma, Pong C. Yuen      117-127
# 100  Yu Tian, Guansong Pang, Fengbei Liu, Yuanhong ...      128-140
# 101  Han Li, Long Chen, Hu Han, Ying Chi, S. Kevin ...      141-152
# 102        Chong Yin, Siqi Liu, Rui Shao, Pong C. Yuen      153-162
# 103  Xiaohan Xing, Yuenan Hou, Hang Li, Yixuan Yuan...      163-173
# 104  Dongren Yao, Erkun Yang, Hao Guan, Jing Sui, Z...      174-184
# 105  Yuan-Xing Zhao, Yan-Ming Zhang, Ming Song, Che...      185-194
# 106                         Tianyi Zhao, Zhaozheng Yin      195-204
# 107  Peng Huang, Xiuzhuang Zhou, Zeqiang Wei, Guodo...      205-214
# 108  Mohammed S. M. Elbaz, Chris Malaisrie, Patrick...      215-224
# 109                                Raunak Dey, Yi Hong      236-247
# 110  Hao Guan, Yunbi Liu, Shifu Xiao, Ling Yue, Min...      248-258
# 111  Yingda Xia, Jiawen Yao, Le Lu, Lingyun Huang, ...      259-269
# 112  Bowen Li, Xinping Ren, Ke Yan, Le Lu, Lingyun ...      270-280
# 113  Zhiming Cui, Changjian Li, Lei Yang, Chunfeng ...      281-290
# 114  Hieu T. Nguyen, Hieu H. Pham, Nghia T. Nguyen,...      291-301
# 115  Lingyun Wu, Zhiqiang Hu, Yuanfeng Ji, Ping Luo...      302-312
# 116  Adrian Galdran, Gustavo Carneiro, Miguel A. Go...      323-333
# 117  Fernando Pérez-García, Catherine Scott, Rachel...      334-344
# 118  Yinhao Ren, Jiafeng Lu, Zisheng Liang, Lars J....      345-354
# 119  Junlin Xian, Zhiwei Wang, Kwang-Ting Cheng, Xi...      355-365
# 120          Tzu-Ming Harry Hsu, Yin-Chih Chelsea Wang      366-376
# 121  Long Huo, Bin Cai, Pengpeng Liang, Zhiyong Sun...      377-386
# 122  Yiting Ma, Xuejin Chen, Kai Cheng, Yang Li, Bi...      387-396
# 123  Yang Yang, Zhiying Cui, Junjie Xu, Changhong Z...      397-406
# 124  Kanghao Chen, Yifan Mao, Huijuan Lu, Chenghua ...      407-417
# 125  Zhuowei Li, Qing Xia, Zhiqiang Hu, Wenji Wang,...      418-428
# 126  Zelin Qiu, Yongsheng Pan, Jie Wei, Dijia Wu, Y...      439-448
# 127  Yuexiang Li, Yanping Wang, Guang Lin, Yi Lin, ...      449-458
# 128  Yangwen Hu, Zhehao Zhong, Ruixuan Wang, Hongme...      469-479
# 129  Yongsheng Pan, Yuanyuan Chen, Dinggang Shen, Y...      480-489
# 130  Jaein Lee, Eunsong Kang, Eunjin Jeon, Heung-Il...      500-509
# 131  Chenchen Qin, Haoming Li, Yixun Liu, Hong Shan...      510-518
# 132  Jinghan Sun, Dong Wei, Kai Ma, Liansheng Wang,...      519-529
# 133  Lisette Lockhart, Parvaneh Saeedi, Jason Au, J...      540-549
# 134    Yan Li, Kai Lan, Xiaoyi Chen, Li Quan, Ni Zhang      561-570
# 135  Jiancheng Yang, Yi He, Kaiming Kuang, Zudi Lin...      571-580
# 136  Jeremy Tan, Benjamin Hou, Thomas Day, John Sim...      581-591
# 137  Sathyanarayanan N. Aakur, Sai Narayanan, Vinee...      592-602
# 138    Yang Yu, Peng Hu, Jie Lin, Pavitra Krishnaswamy      603-613
# 139                  Shanmukh Alle, U. Deva Priyakumar      614-623
# 140  Apostolia Tsirikoglou, Karin Stacke, Gabriel E...      624-633
# 141  Giacomo Nebbia, Saba Dadsetan, Dooman Arefan, ...      634-643
# 142  Riqiang Gao, Yucheng Tang, Kaiwen Xu, Ho Hin L...      647-656
# 143  Hui Cui, Ping Xuan, Qiangguo Jin, Mingjun Ding...      657-666
# 144  Nathaniel Braman, Jacob W. H. Gordon, Emery T....      667-677
# 145  Sebastian Pölsterl, Tom Nuno Wolf, Christian W...      688-698
# 146  Mahsa Ghorbani, Mojtaba Bahrami, Anees Kazi, M...      709-718
# 147  Yulu Guan, Hui Cui, Yiyue Xu, Qiangguo Jin, Ti...      721-730
# 148  Jia-Ren Chang, Ching-Yi Lee, Chi-Chung Chen, J...      731-740
# 149  Ting Xiao, Han Zheng, Xiaoning Wang, Xinghan C...      741-751
# 150  Jianan Chen, Helen M. C. Cheung, Laurent Milot...      752-761
# 151  Saloni Agarwal, Mohamedelfatih Eltigani Osman ...      762-771
# 152  Yoel Shoshan, Aviad Zlotnick, Vadim Ratner, Da...      772-781
# 153   Jacob C. Reinhold, Aaron Carass, Jerry L. Prince      782-792
# 154                Yangsibo Huang, Xiaoxiao Li, Kai Li      793-803
# 155  Nkechinyere N. Agu, Joy T. Wu, Hanqing Chao, I...      804-813
# 156  Xianjing Liu, Bo Li, Esther E. Bron, Wiro J. N...      814-823
# 157  Aishik Konwer, Joseph Bae, Gagandeep Singh, Ri...      824-833
#
#                                        DOI  Year of publication  \
# 94    /chapter/10.1007/978-3-030-87240-3_3                 2021
# 95    /chapter/10.1007/978-3-030-87240-3_5                 2021
# 96    /chapter/10.1007/978-3-030-87240-3_6                 2021
# 97    /chapter/10.1007/978-3-030-87240-3_7                 2021
# 98   /chapter/10.1007/978-3-030-87240-3_10                 2021
# 99   /chapter/10.1007/978-3-030-87240-3_12                 2021
# 100  /chapter/10.1007/978-3-030-87240-3_13                 2021
# 101  /chapter/10.1007/978-3-030-87240-3_14                 2021
# 102  /chapter/10.1007/978-3-030-87240-3_15                 2021
# 103  /chapter/10.1007/978-3-030-87240-3_16                 2021
# 104  /chapter/10.1007/978-3-030-87240-3_17                 2021
# 105  /chapter/10.1007/978-3-030-87240-3_18                 2021
# 106  /chapter/10.1007/978-3-030-87240-3_19                 2021
# 107  /chapter/10.1007/978-3-030-87240-3_20                 2021
# 108  /chapter/10.1007/978-3-030-87240-3_21                 2021
# 109  /chapter/10.1007/978-3-030-87240-3_23                 2021
# 110  /chapter/10.1007/978-3-030-87240-3_24                 2021
# 111  /chapter/10.1007/978-3-030-87240-3_25                 2021
# 112  /chapter/10.1007/978-3-030-87240-3_26                 2021
# 113  /chapter/10.1007/978-3-030-87240-3_27                 2021
# 114  /chapter/10.1007/978-3-030-87240-3_28                 2021
# 115  /chapter/10.1007/978-3-030-87240-3_29                 2021
# 116  /chapter/10.1007/978-3-030-87240-3_31                 2021
# 117  /chapter/10.1007/978-3-030-87240-3_32                 2021
# 118  /chapter/10.1007/978-3-030-87240-3_33                 2021
# 119  /chapter/10.1007/978-3-030-87240-3_34                 2021
# 120  /chapter/10.1007/978-3-030-87240-3_35                 2021
# 121  /chapter/10.1007/978-3-030-87240-3_36                 2021
# 122  /chapter/10.1007/978-3-030-87240-3_37                 2021
# 123  /chapter/10.1007/978-3-030-87240-3_38                 2021
# 124  /chapter/10.1007/978-3-030-87240-3_39                 2021
# 125  /chapter/10.1007/978-3-030-87240-3_40                 2021
# 126  /chapter/10.1007/978-3-030-87240-3_42                 2021
# 127  /chapter/10.1007/978-3-030-87240-3_43                 2021
# 128  /chapter/10.1007/978-3-030-87240-3_45                 2021
# 129  /chapter/10.1007/978-3-030-87240-3_46                 2021
# 130  /chapter/10.1007/978-3-030-87240-3_48                 2021
# 131  /chapter/10.1007/978-3-030-87240-3_49                 2021
# 132  /chapter/10.1007/978-3-030-87240-3_50                 2021
# 133  /chapter/10.1007/978-3-030-87240-3_52                 2021
# 134  /chapter/10.1007/978-3-030-87240-3_54                 2021
# 135  /chapter/10.1007/978-3-030-87240-3_55                 2021
# 136  /chapter/10.1007/978-3-030-87240-3_56                 2021
# 137  /chapter/10.1007/978-3-030-87240-3_57                 2021
# 138  /chapter/10.1007/978-3-030-87240-3_58                 2021
# 139  /chapter/10.1007/978-3-030-87240-3_59                 2021
# 140  /chapter/10.1007/978-3-030-87240-3_60                 2021
# 141  /chapter/10.1007/978-3-030-87240-3_61                 2021
# 142  /chapter/10.1007/978-3-030-87240-3_62                 2021
# 143  /chapter/10.1007/978-3-030-87240-3_63                 2021
# 144  /chapter/10.1007/978-3-030-87240-3_64                 2021
# 145  /chapter/10.1007/978-3-030-87240-3_66                 2021
# 146  /chapter/10.1007/978-3-030-87240-3_68                 2021
# 147  /chapter/10.1007/978-3-030-87240-3_69                 2021
# 148  /chapter/10.1007/978-3-030-87240-3_70                 2021
# 149  /chapter/10.1007/978-3-030-87240-3_71                 2021
# 150  /chapter/10.1007/978-3-030-87240-3_72                 2021
# 151  /chapter/10.1007/978-3-030-87240-3_73                 2021
# 152  /chapter/10.1007/978-3-030-87240-3_74                 2021
# 153  /chapter/10.1007/978-3-030-87240-3_75                 2021
# 154  /chapter/10.1007/978-3-030-87240-3_76                 2021
# 155  /chapter/10.1007/978-3-030-87240-3_77                 2021
# 156  /chapter/10.1007/978-3-030-87240-3_78                 2021
# 157  /chapter/10.1007/978-3-030-87240-3_79                 2021
#
#      Part of publication                  category  Number of references  \
# 94                     5  category: classification                    22
# 95                     5  category: classification                    14
# 96                     5  category: classification                    29
# 97                     5  category: classification                    45
# 98                     5  category: classification                    35
# 99                     5  category: classification                    22
# 100                    5  category: classification                    41
# 101                    5  category: classification                    35
# 102                    5  category: classification                    26
# 103                    5  category: classification                    29
# 104                    5  category: classification                    32
# 105                    5  category: classification                    21
# 106                    5  category: classification                    20
# 107                    5  category: classification                    24
# 108                    5  category: classification                    18
# 109                    5  category: classification                    28
# 110                    5  category: classification                    28
# 111                    5  category: classification                    29
# 112                    5  category: classification                    25
# 113                    5  category: classification                    18
# 114                    5  category: classification                    33
# 115                    5  category: classification                    27
# 116                    5  category: classification                    25
# 117                    5  category: classification                    13
# 118                    5  category: classification                    20
# 119                    5  category: classification                    21
# 120                    5  category: classification                    19
# 121                    5  category: classification                    17
# 122                    5  category: classification                    27
# 123                    5  category: classification                    20
# 124                    5  category: classification                    28
# 125                    5  category: classification                    21
# 126                    5  category: classification                    23
# 127                    5  category: classification                    15
# 128                    5  category: classification                    28
# 129                    5  category: classification                    15
# 130                    5  category: classification                    23
# 131                    5  category: classification                    11
# 132                    5  category: classification                    33
# 133                    5  category: classification                    20
# 134                    5  category: classification                    16
# 135                    5  category: classification                    26
# 136                    5  category: classification                    33
# 137                    5  category: classification                    31
# 138                    5  category: classification                    30
# 139                    5  category: classification                    22
# 140                    5  category: classification                    24
# 141                    5  category: classification                    23
# 142                    5  category: classification                    28
# 143                    5  category: classification                    19
# 144                    5  category: classification                    21
# 145                    5  category: classification                    29
# 146                    5  category: classification                    30
# 147                    5  category: classification                    22
# 148                    5  category: classification                    23
# 149                    5  category: classification                    27
# 150                    5  category: classification                    23
# 151                    5  category: classification                    20
# 152                    5  category: classification                    15
# 153                    5  category: classification                    34
# 154                    5  category: classification                    19
# 155                    5  category: classification                    34
# 156                    5  category: classification                    21
# 157                    5  category: classification                    15
#
#      Oldest reference  Newest reference  Range of references
# 94               1991              2020                   29
# 95               1996              2020                   24
# 96               2003              2021                   18
# 97               1987              2021                   34
# 98               2010              2020                   10
# 99               2009              2020                   11
# 100              1999              2021                   22
# 101              2015              2021                    6
# 102              2005              2020                   15
# 103              2014              2020                    6
# 104              1972              2021                   49
# 105              1998              2020                   22
# 106              2000              2019                   19
# 107              2004              2021                   17
# 108              2000              2019                   19
# 109              1997              2021                   24
# 110              2008              2021                   13
# 111              2013              2021                    8
# 112              1954              2021                   67
# 113              2007              2021                   14
# 114              1950              2021                   71
# 115              2008              2021                   13
# 116              2002              2021                   19
# 117              2002              2019                   17
# 118              2004              2020                   16
# 119              2006              2021                   15
# 120              1992              2020                   28
# 121              2015              2020                    5
# 122              2004              2020                   16
# 123              2012              2020                    8
# 124              1997              2020                   23
# 125              1986              2019                   33
# 126              2007              2021                   14
# 127              2007              2020                   13
# 128              1987              2021                   34
# 129              2008              2020                   12
# 130              1992              2020                   28
# 131              2009              2020                   11
# 132              2006              2021                   15
# 133              1997              2020                   23
# 134              2014              2020                    6
# 135              2004              2021                   17
# 136              2000              2021                   21
# 137              2003              2021                   18
# 138              1998              2021                   23
# 139              1975              2021                   46
# 140              2000              2021                   21
# 141              1988              2021                   33
# 142              1976              2021                   45
# 143              2015              2021                    6
# 144              1947              2021                   74
# 145              1972              2021                   49
# 146              2002              2021                   19
# 147              2016              2021                    5
# 148              1997              2020                   23
# 149              2001              2021                   20
# 150              1996              2021                   25
# 151              1982              2020                   38
# 152              1999              2021                   22
# 153              2008              2021                   13
# 154              1996              2020                   24
# 155              2013              2021                    8
# 156              2003              2021                   18
# 157              2014              2021                    7

# %%
df_2012class.head(30)
# Out:
#     index                                              Title  \
# 0       4    Surgical Gesture Classification from Video Data
# 1       7  Efficient Optic Cup Detection from Intra-image...
# 2       9  Thoracic Abnormality Detection with Data Adapt...
# 3      10  Domain Transfer Learning for MCI Conversion Pr...
# 4      12  Incremental Kernel Ridge Regression for the Pr...
# 5      13  Fuzzy Multi-class Statistical Modeling for Eff...
# 6      14  Structure and Context in Prostatic Gland Segme...
# 7      15  Quantitative Characterization of Trabecular Bo...
# 8      16  Genetic, Structural and Functional Imaging Bio...
# 9      17  Robust MR Spine Detection Using Hierarchical L...
# 10     19  A Visual Latent Semantic Approach for Automati...
# 11     20  Detection of Spontaneous Vesicle Release at In...
# 12     25  Classification of Ambiguous Nerve Fiber Orient...
# 13     28  Bi-exponential Magnetic Resonance Signal Model...
# 14     31  Dictionary Learning and Time Sparsity in Dynam...
# 15     33  Sparsity-Based Deconvolution of Low-Dose Perfu...
# 16     36  Oriented Pattern Analysis for Streak Detection...
# 17     37  Automated Foveola Localization in Retinal 3D-O...
# 18     38  Intrinsic Melanin and Hemoglobin Colour Compon...
# 19     40  Apoptosis Detection for Adherent Cell Populati...
# 20     41     Modeling Dynamic Cellular Morphology in Images
# 21     42  Learning to Detect Cells Using Non-overlapping...
# 22     51  Modeling of Multi-View 3D Freehand Radio Frequ...
# 23     52  Towards Intra-operative PET for Head and Neck ...
# 24     53  Data-Driven Breast Decompression and Lesion Ma...
# 25     55  Development of an MRI-Compatible Device for Pr...
# 26     59  Towards Computer-Assisted Deep Brain Stimulati...
# 27     61  Combining CRF and Multi-hypothesis Detection f...
# 28     62                     Hierarchical Manifold Learning
# 29     82  Localization of Sparse Transmural Excitation S...
#
#                                               Authors Page numbers  \
# 0      Benjamín Béjar Haro, Luca Zappella, René Vidal        34-41
# 1   Yanwu Xu, Jiang Liu, Stephen Lin, Dong Xu, Car...        58-65
# 2        Yang Song, Weidong Cai, Yun Zhou, Dagan Feng        74-81
# 3             Bo Cheng, Daoqiang Zhang, Dinggang Shen        82-90
# 4   Binbin Pan, James J. Xia, Peng Yuan, Jaime Gat...       99-106
# 5   Jose George, Kathleen Vunckx, Elke Van de Cast...      107-114
# 6           Kien Nguyen, Anindya Sarkar, Anil K. Jain      115-123
# 7                Yinxiao Liu, Punam K. Saha, Ziyue Xu      124-131
# 8   Nikhil Singh, Angela Y. Wang, Preethi Sankaran...      132-140
# 9   Yiqiang Zhan, Dewan Maneesh, Martin Harder, Xi...      141-148
# 10  Angel Cruz-Roa, Fabio González, Joseph Galaro,...      157-164
# 11         Stefan Sokoll, Klaus Tönnies, Martin Heine      165-172
# 12  Melanie Kleiner, Markus Axer, David Gräßel, Ju...      206-213
# 13  Quentin Duché, Oscar Acosta, Giulio Gambarota,...      231-238
# 14  Jose Caballero, Daniel Rueckert, Joseph V. Hajnal      256-263
# 15           Ruogu Fang, Tsuhan Chen, Pina C. Sanelli      272-280
# 16  Maryam Sadeghi, Tim K. Lee, David McLean, Harv...      298-306
# 17  Yu-Ying Liu, Hiroshi Ishikawa, Mei Chen, Gadi ...      307-314
# 18  Ali Madooei, Mark S. Drew, Maryam Sadeghi, M. ...      315-322
# 19  Seungil Huh, Dai Fei Elmer Ker, Hang Su, Takeo...      331-339
# 20  Xing An, Zhiwen Liu, Yonggang Shi, Ning Li, Ya...      340-347
# 21  Carlos Arteta, Victor Lempitsky, J. Alison Nob...      348-356
# 22                 T. Klein, M. Hansson, Nassir Navab      422-429
# 23  Dzhoshkun I. Shakir, Asli Okur, Alexander Hart...      430-437
# 24  Michael Wels, B. M. Kelm, M. Hammon, Anna Jere...      438-446
# 25  Jeremy Cepek, Blaine Chronik, Uri Lindner, Joh...      455-462
# 26  Silvain Bériault, Yiming Xiao, Lara Bailey, D....      487-494
# 27  Zhihui Hao, Qiang Wang, Yeong Kyeong Seong, Jo...      504-511
# 28  Kanwal K. Bhatia, Anil Rao, Anthony N. Price, ...      512-519
# 29  Jingjia Xu, Azar Rahimi Dehaghani, Fei Gao, Li...      675-682
#
#                                       DOI  Year of publication  \
# 0    /chapter/10.1007/978-3-642-33415-3_5               2012.0
# 1    /chapter/10.1007/978-3-642-33415-3_8               2012.0
# 2   /chapter/10.1007/978-3-642-33415-3_10               2012.0
# 3   /chapter/10.1007/978-3-642-33415-3_11               2012.0
# 4   /chapter/10.1007/978-3-642-33415-3_13               2012.0
# 5   /chapter/10.1007/978-3-642-33415-3_14               2012.0
# 6   /chapter/10.1007/978-3-642-33415-3_15               2012.0
# 7   /chapter/10.1007/978-3-642-33415-3_16               2012.0
# 8   /chapter/10.1007/978-3-642-33415-3_17               2012.0
# 9   /chapter/10.1007/978-3-642-33415-3_18               2012.0
# 10  /chapter/10.1007/978-3-642-33415-3_20               2012.0
# 11  /chapter/10.1007/978-3-642-33415-3_21               2012.0
# 12  /chapter/10.1007/978-3-642-33415-3_26               2012.0
# 13  /chapter/10.1007/978-3-642-33415-3_29               2012.0
# 14  /chapter/10.1007/978-3-642-33415-3_32               2012.0
# 15  /chapter/10.1007/978-3-642-33415-3_34               2012.0
# 16  /chapter/10.1007/978-3-642-33415-3_37               2012.0
# 17  /chapter/10.1007/978-3-642-33415-3_38               2012.0
# 18  /chapter/10.1007/978-3-642-33415-3_39               2012.0
# 19  /chapter/10.1007/978-3-642-33415-3_41               2012.0
# 20  /chapter/10.1007/978-3-642-33415-3_42               2012.0
# 21  /chapter/10.1007/978-3-642-33415-3_43               2012.0
# 22  /chapter/10.1007/978-3-642-33415-3_52               2012.0
# 23  /chapter/10.1007/978-3-642-33415-3_53               2012.0
# 24  /chapter/10.1007/978-3-642-33415-3_54               2012.0
# 25  /chapter/10.1007/978-3-642-33415-3_56               2012.0
# 26  /chapter/10.1007/978-3-642-33415-3_60               2012.0
# 27  /chapter/10.1007/978-3-642-33415-3_62               2012.0
# 28  /chapter/10.1007/978-3-642-33415-3_63               2012.0
# 29  /chapter/10.1007/978-3-642-33415-3_83               2012.0
#
#     Part of publication                  category  Number of references  \
# 0                     1  category: classification                    26
# 1                     1  category: classification                    16
# 2                     1  category: classification                    12
# 3                     1  category: classification                    15
# 4                     1  category: classification                    11
# 5                     1  category: classification                    12
# 6                     1  category: classification                    10
# 7                     1  category: classification                    19
# 8                     1  category: classification                    10
# 9                     1  category: classification                     9
# 10                    1  category: classification                    10
# 11                    1  category: classification                    15
# 12                    1  category: classification                     9
# 13                    1  category: classification                    14
# 14                    1  category: classification                    17
# 15                    1  category: classification                    11
# 16                    1  category: classification                    10
# 17                    1  category: classification                    12
# 18                    1  category: classification                    14
# 19                    1  category: classification                     6
# 20                    1  category: classification                    11
# 21                    1  category: classification                    15
# 22                    1  category: classification                    19
# 23                    1  category: classification                     9
# 24                    1  category: classification                    12
# 25                    1  category: classification                    12
# 26                    1  category: classification                    15
# 27                    1  category: classification                    16
# 28                    1  category: classification                    16
# 29                    1  category: classification                    10
#
#     Oldest reference  Newest reference  Range of references
# 0               1999              2012                   13
# 1               1992              2011                   19
# 2               2004              2011                    7
# 3               2001              2012                   11
# 4               1985              2009                   24
# 5               1977              2011                   34
# 6               1992              2012                   20
# 7               1985              2011                   26
# 8               1994              2012                   18
# 9               1989              2012                   23
# 10              1991              2011                   20
# 11              1992              2011                   19
# 12              2001              2012                   11
# 13              1991              2011                   20
# 14              2003              2011                    8
# 15              1996              2012                   16
# 16              1987              2012                   25
# 17              1994              2011                   17
# 18              1979              2010                   31
# 19              2002              2012                   10
# 20              1981              2011                   30
# 21              1988              2011                   23
# 22              1946              2011                   65
# 23              1975              2011                   36
# 24              1987              2011                   24
# 25              1992              2012                   20
# 26              2000              2012                   12
# 27              1995              2011                   16
# 28              2003              2012                    9
# 29              1969              2011                   42
