# %%
import pandas as pd
import re

# %%
#reading in files
df_2012 = pd.read_csv(r'C:\Users\chris\Desktop\Value-Analysis-Thesis\02-mining-inital-data\database_miccai_2012.csv')
df_2021 = pd.read_csv(r'C:\Users\chris\Desktop\Value-Analysis-Thesis\02-mining-inital-data\database_miccai_2021.csv')

# %%
#removing unnecessary index column
df_2012 = df_2012.drop("Unnamed: 0", axis = 1)
df_2021 = df_2021.drop("Unnamed: 0", axis = 1)

# %% [markdown]
# ## Defining categories
# Making a set of helper methods to create the dictionaries for each article with words to search for, defining the keywords and the rules, checking everything and adding a threshold check to filter out categories with insufficient information found

# %%
#first I create a dictionary of the words in the string
#having it as a separate method means only running it once
def create_string_dic(string):
    list_of_words = string.split(" ")
    string_dictionary = {}
    for word in list_of_words:
        word = word.lower().strip() #making all words lower case and removing all white spaces
        if word in string_dictionary: #will return true if word already is assigned a value
            string_dictionary[word] = string_dictionary.get(word) + 1
        else:
            string_dictionary[word] = 1
    return string_dictionary

# %%
#function that checks for keyword matches 
def check_for_keywords(string_dic, keywords_dic):
    running_counter = 0
    for word in keywords_dic.keys():
        if word in string_dic: #will add value if it exists, otherwise will give the keyword a 0
            keywords_dic.get(word).append(string_dic.get(word))
            running_counter += string_dic.get(word)
            #running_counter += 1
        else:
            keywords_dic.get(word).append(0)
        if 'category' in word: #the last keyword is the category which should
            #correspond to the running counter instead of 0 (as I am reasonably sure the word 'category: keyword_category')
            #does not occur in the strings I am searching
            keywords_dic.get(word)[-1] = (running_counter)

    return keywords_dic

# %%
#finding the abstracts
def find_abstract(year, place):
    abstract_list = []
    with open(place, "r", encoding = 'utf-8') as part:
        article = part.read()           
        abstracts = [i.start() for i in re.finditer("Abstract", article)]
        for index in abstracts: 
            if year == 2012 and article[index+8] != "s": #removing the "Abstracts", aka the references in 2012
                abstract_list.append(article[index:index+2000])
            elif year == 2021 and article[index+9] != "T": #removing the references in 2021 ("abstract track")
                abstract_list.append(article[index:index+2000])
    return abstract_list

# %%
#method creating dictionary of abstract and title to search through 
def creating_dic(year, place, df):
    #saving the abstract
    abstract_list = find_abstract(year, place)
    #creating the list of dictionaries for each article
    list_of_dic = []
    #getting the title to combine with the abstract
    titles = df['Title'].to_list()
    #combining title and abstract
    for index in range(len(titles)):
        titles[index] = titles[index] + " " + abstract_list[index]
    #creating dictionary of strings to search through - only run once(technically)
    for title in titles:
        list_of_dic.append(create_string_dic(title))
    return list_of_dic

# %%
dic2012 = creating_dic(2012, r"C:\Users\chris\Desktop\Value-Analysis-Thesis\01-combining-proceedings-txt\miccai_2012_full_txt.txt", df_2012)
dic2021 = creating_dic(2021, r"C:\Users\chris\Desktop\Value-Analysis-Thesis\01-combining-proceedings-txt\miccai_2021_full_txt.txt", df_2021)

# %%
#initialising the keyword dictionary and searching the strings for the given key words
#creating a dataframe where each column is a keyword and the value is the number of occurences of that word 
#each row corresponds to the index of the article
def generate_keyword_search_df(keywords, list_of_dic):
    initial_keywords_dic = {key:[] for key in keywords}
    for index in range(len(list_of_dic)):
        keyword_dic = (check_for_keywords(list_of_dic[index], initial_keywords_dic))
    df = pd.DataFrame(keyword_dic) 
    return df

# %%
#reading in the keywords file and creating the list of lowercase words to check for
def reading_keywords(place):
    with open(place, "r", encoding = 'utf-8') as part:
        string = part.read()
        string = string.lower()
        keywords = string.split('\n') 
    return keywords

# %%
#method for checking the rules
def check_rules(df, rules_file):
    category = 'category: ' + rules_file[:len(rules_file)-6]
    with open(rules_file, "r", encoding = 'utf-8') as part:
        string = part.read()
        string = string.lower()
        rules = string.split('\n') 
        
        for index in range(len(df)):
            for rule in rules:
                threshold = 0
                element_exists = True
                elements = rule.split(' + ')
                for i in range(len(elements)):   
                    threshold += df.loc[index, elements[i].strip()]
                    if df.loc[index, elements[i].strip()] == 0:
                        element_exists = False #if just one isn't there, set to false and do not allow rule to add one
                if threshold == len(elements) and element_exists: #meaning each element in the rule was present 
                    df.loc[index, category] +=1
                           
    return df[category]

# %%
#method combining the helper methods above and adding the threshold check defined below

def search_and_check(keywords_list, rules_list, dic):
    #checking the classification keywords first and their rules
    dfA = check_rules(generate_keyword_search_df(reading_keywords(keywords_list[0]), dic), rules_list[0])
    #then checking the other keywords and their rules
    dfB = check_rules(generate_keyword_search_df(reading_keywords(keywords_list[1]), dic), rules_list[1])
    
    #merging the two found dataframes
    df = pd.merge(dfA, dfB, right_index = True, left_index = True)
    
    #adding the category of the column with the most highest value found in the search
    category = df.idxmax(axis = 1)
    category.name = 'category'
    df= df.join(category)
    #doing the threshold check to add the unknown category for both columns less than two (meaning low indication of either)
    #or same value in both columns (meaning no indiation either way)
    df = threshold_check(df)
    #only the final category series is returned (to be added to original database)
    
    return df['category']

# %%
#helper method to ensure keyword/rule results are not arbitrarily added if not enough information 
#was found
def threshold_check(df):
    unknown = 'category: unknown'
    for i in range(len(df)):
        if df.iloc[i, 0] < 2 and df.iloc[i, 1] < 2: #checking if both columns are below 2, meaning low indication of either category
            df.loc[i, 'category'] = unknown
        elif df.iloc[i, 0] == df.iloc[i, 1]: #adding a check if they are the same, then no indication either way
            df.loc[i, 'category'] = unknown
    return df

# %%
keywords_list= ['classification-keywords', 'other-keywords']
rules_list = ['classification-rules', 'other-rules']

df2012_category=search_and_check(keywords_list, rules_list, dic2012)
df2021_category=search_and_check(keywords_list, rules_list, dic2021)

# %%
#adding the newly found categories
df_2012 = df_2012.join(df2012_category)
df_2021 = df_2021.join(df2021_category)

# %%
#filtering on classification only to be saved as a csv
df2012_class = df_2012[df_2012['category'] == 'category: classification']
df2021_class = df_2021[df_2021['category'] == 'category: classification']

# %%
#saving updated database to csv - used in references mining and analysis notebook
df_2012.to_csv("database_miccai_2012_with_cat.csv")
df_2021.to_csv("database_miccai_2021_with_cat.csv")

# %% [markdown]
# ## Some numbers about the category outcome

# %%
len(df_2012[df_2012['category'] == 'category: classification'])
# Out:
# 90

# %%
len(df_2012[df_2012['category'] == 'category: other'])
# Out:
# 101

# %%
len(df_2012[df_2012['category'] == 'category: unknown'])
# Out:
# 61

# %%
len(df_2021[df_2021['category'] == 'category: classification'])
# Out:
# 286

# %%
len(df_2021[df_2021['category'] == 'category: other'])
# Out:
# 175

# %%
len(df_2021[df_2021['category'] == 'category: unknown'])
# Out:
# 70

# %% [markdown]
# ## Viewing the different parts of proceedings
#
# Used to manually annotate articles

# %%
pd.set_option('display.max_rows', None)

# %%
df2021_class[df2021_class['Part of publication']==5]
# Out:
#                                                  Title  \
# 255  CA-Net: Leveraging Contextual Features for Lun...
# 257  DAE-GCN: Identifying Disease-Related Features ...
# 258  Enhanced Breast Lesion Classification via Know...
# 259  Multiple Meta-model Quantifying for Medical Vi...
# 262  A Coherent Cooperative Learning Framework Base...
# 264  A Segmentation-Assisted Model for Universal Le...
# 265  Constrained Contrastive Distribution Learning ...
# 266  Conditional Training with Bounding Map for Uni...
# 267  Focusing on Clinically Interpretable Features:...
# 268  Categorical Relation-Preserving Contrastive Kn...
# 269  Tensor-Based Multi-index Representation Learni...
# 270  Region Ensemble Network for MCI Conversion Pre...
# 271  Airway Anomaly Detection by Prototype-Based Gr...
# 272  Energy-Based Supervised Hashing for Multimorbi...
# 273  Stochastic 4D Flow Vector-Field Signatures: A ...
# 275  ASC-Net: Adversarial-Based Selective Network f...
# 276  Cost-Sensitive Meta-learning for Progress Pred...
# 277  Effective Pancreatic Cancer Screening on Non-c...
# 278  Learning from Subjective Ratings Using Auto-De...
# 279  VertNet: Accurate Vertebra Localization and Id...
# 280  VinDr-SpineXR: A Deep Learning Framework for S...
# 281  Multi-frame Collaboration for Effective Endosc...
# 283  Balanced-MixUp for Highly Imbalanced Medical I...
# 284  Transfer Learning of Deep Spatiotemporal Netwo...
# 285  Retina-Match: Ipsilateral Mammography Lesion M...
# 286  Towards Robust Dual-View Transformation via De...
# 287  DeepOPG: Improving Orthopantomogram Finding Su...
# 288  Joint Spinal Centerline Extraction and Curvatu...
# 289  LDPolypVideo Benchmark: A Large-Scale Colonosc...
# 290  Continual Learning with Bayesian Model Based o...
# 291  Alleviating Data Imbalance Issue with Perturbe...
# 292  A Deep Reinforced Tree-Traversal Agent for Cor...
# 294  Predicting Symptoms from Multiphasic MRI via M...
# 295  Triplet-Branch Network with Prior-Knowledge Em...
# 297  Data Augmentation in Logit Space for Medical I...
# 298  Collaborative Image Synthesis and Disease Diag...
# 300  Meta-modulation Network for Domain Generalizat...
# 301  3D Brain Midline Delineation for Hematoma Pati...
# 302  Unsupervised Representation Learning Meets Pse...
# 304  Automating Embryo Development Stage Detection ...
# 306  Few Trust Data Guided Annotation Refinement fo...
# 307  Asymmetric 3D Context Fusion for Universal Les...
# 308  Detecting Outliers with Poisson Image Interpol...
# 309  MG-NET: Leveraging Pseudo-imaging for Multi-mo...
# 310  Multimodal Multitask Deep Learning for X-Ray I...
# 311  Linear Prediction Residual for Efficient Diagn...
# 312  Primary Tumor and Inter-Organ Augmentations fo...
# 313  Radiomics-Informed Deep Curriculum Learning fo...
# 314  Lung Cancer Risk Estimation with Incomplete Da...
# 315  Co-graph Attention Reasoning Based Imaging and...
# 316  Deep Orthogonal Fusion: Multimodal Prognostic ...
# 318  Combining 3D Image and Tabular Data via the Dy...
# 320  GKD: Semi-supervised Graph Knowledge Distillat...
# 327  10.1007/978-3-030-87240-3_75                 2021                    5
# 328  10.1007/978-3-030-87240-3_76                 2021                    5
# 329  10.1007/978-3-030-87240-3_77                 2021                    5
# 330  10.1007/978-3-030-87240-3_78                 2021                    5
# 331  10.1007/978-3-030-87240-3_79                 2021                    5
#
#                      category
# 255  category: classification
# 257  category: classification
# 258  category: classification
# 259  category: classification
# 262  category: classification
# 264  category: classification
# 265  category: classification
# 266  category: classification
# 267  category: classification
# 268  category: classification
# 269  category: classification
# 270  category: classification
# 271  category: classification
# 272  category: classification
# 273  category: classification
# 275  category: classification
# 276  category: classification
# 277  category: classification
# 278  category: classification
# 279  category: classification
# 280  category: classification
# 281  category: classification
# 283  category: classification
# 284  category: classification
# 285  category: classification
# 286  category: classification
# 287  category: classification
# 288  category: classification
# 289  category: classification
# 290  category: classification
# 291  category: classification
# 292  category: classification
# 294  category: classification
# 295  category: classification
# 297  category: classification
# 298  category: classification
# 300  category: classification
# 301  category: classification
# 302  category: classification
# 304  category: classification
# 306  category: classification
# 307  category: classification
# 308  category: classification
# 309  category: classification
# 310  category: classification
# 311  category: classification
# 312  category: classification
# 313  category: classification
# 314  category: classification
# 315  category: classification
# 316  category: classification
# 318  category: classification
# 320  category: classification
# 321  category: classification
# 322  category: classification
# 323  category: classification
# 324  category: classification
# 325  category: classification
# 326  category: classification
# 327  category: classification
# 328  category: classification
# 329  category: classification
# 330  category: classification
# 331  category: classification

# %%
df2021_class[df2021_class['Part of publication']==2]
# Out:
#                                                  Title  \
# 69   SSLP: Spatial Guided Self-supervised Learning ...
# 72   Imbalance-Aware Self-supervised Learning for 3...
# 73   Self-supervised Visual Representation Learning...
# 74   Contrastive Learning with Continuous Proxy Met...
# 76   Self-supervised Longitudinal Neighbourhood Emb...
# 78   SimTriplet: Simple Triplet Representation Lear...
# 79   Lesion-Based Contrastive Learning for Diabetic...
# 80   SAR: Scale-Aware Restoration Learning for 3D T...
# 82   SpineGEM: A Hybrid-Supervised Model Generation...
# 83   Contrastive Learning of Relative Position Regr...
# 84   Topological Learning and Its Application to Mu...
# 86   Implicit Field Learning for Unsupervised Anoma...
# 87   Dual-Consistency Semi-supervised Learning with...
# 88   Contrastive Pre-training and Representation Di...
# 89   Positional Contrastive Learning for Volumetric...
# 90   Longitudinal Self-supervision to Disentangle I...
# 91   Self-supervised Vessel Enhancement Using Flow-...
# 92   Unsupervised Contrastive Learning of Radiomics...
# 94   Multimodal Representation Learning via Maximiz...
# 95   Inter-regional High-Level Relation Learning fr...
# 100  Lesion Segmentation and RECIST Diameter Predic...
# 101  Reciprocal Learning for Semi-supervised Segmen...
# 102  Disentangled Sequential Graph Autoencoder for ...
# 104  3D Semantic Mapping from Arthroscopy Using Out...
# 106  Implicit Neural Distance Representation for Un...
# 109     Neighbor Matching for Semi-supervised Learning
# 112  Order-Guided Disentangled Representation Learn...
# 113  Semi-supervised Contrastive Learning for Label...
# 114  Functional Magnetic Resonance Imaging Data Aug...
# 118  OXnet: Deep Omni-Supervised Thoracic Disease D...
# 121  Improving Pneumonia Localization via Cross-Att...
# 78   10.1007/978-3-030-87196-3_10                 2021                    2
# 79   10.1007/978-3-030-87196-3_11                 2021                    2
# 80   10.1007/978-3-030-87196-3_12                 2021                    2
# 82   10.1007/978-3-030-87196-3_14                 2021                    2
# 83   10.1007/978-3-030-87196-3_15                 2021                    2
# 84   10.1007/978-3-030-87196-3_16                 2021                    2
# 86   10.1007/978-3-030-87196-3_18                 2021                    2
# 87   10.1007/978-3-030-87196-3_19                 2021                    2
# 88   10.1007/978-3-030-87196-3_20                 2021                    2
# 89   10.1007/978-3-030-87196-3_21                 2021                    2
# 90   10.1007/978-3-030-87196-3_22                 2021                    2
# 91   10.1007/978-3-030-87196-3_23                 2021                    2
# 92   10.1007/978-3-030-87196-3_24                 2021                    2
# 94   10.1007/978-3-030-87196-3_26                 2021                    2
# 95   10.1007/978-3-030-87196-3_27                 2021                    2
# 100  10.1007/978-3-030-87196-3_32                 2021                    2
# 101  10.1007/978-3-030-87196-3_33                 2021                    2
# 102  10.1007/978-3-030-87196-3_34                 2021                    2
# 104  10.1007/978-3-030-87196-3_36                 2021                    2
# 106  10.1007/978-3-030-87196-3_38                 2021                    2
# 109  10.1007/978-3-030-87196-3_41                 2021                    2
# 112  10.1007/978-3-030-87196-3_44                 2021                    2
# 113  10.1007/978-3-030-87196-3_45                 2021                    2
# 114  10.1007/978-3-030-87196-3_46                 2021                    2
# 118  10.1007/978-3-030-87196-3_50                 2021                    2
# 121  10.1007/978-3-030-87196-3_53                 2021                    2
# 122  10.1007/978-3-030-87196-3_54                 2021                    2
# 124  10.1007/978-3-030-87196-3_56                 2021                    2
#
#                      category
# 69   category: classification
# 72   category: classification
# 73   category: classification
# 74   category: classification
# 76   category: classification
# 78   category: classification
# 79   category: classification
# 80   category: classification
# 82   category: classification
# 83   category: classification
# 84   category: classification
# 86   category: classification
# 87   category: classification
# 88   category: classification
# 89   category: classification
# 90   category: classification
# 91   category: classification
# 92   category: classification
# 94   category: classification
# 95   category: classification
# 100  category: classification
# 101  category: classification
# 102  category: classification
# 104  category: classification
# 106  category: classification
# 109  category: classification
# 112  category: classification
# 113  category: classification
# 114  category: classification
# 118  category: classification
# 121  category: classification
# 122  category: classification
# 124  category: classification

# %%
df2021_class[df2021_class['Part of publication']==3]
# Out:
#                                                  Title  \
# 131  Targeted Gradient Descent: A Novel Method for ...
# 132  A Hierarchical Feature Constraint to Camouflag...
# 135  AlignTransformer: Hierarchical Alignment of Vi...
# 136          Continuous-Time Deep Glioma Growth Models
# 137  Spine-Transformers: Vertebra Detection and Loc...
# 138  Multi-view Analysis of Unregistered Medical Im...
# 139  Stain Mix-Up: Unsupervised Domain Generalizati...
# 141  Generative Self-training for Cross-Domain Unsu...
# 145     Harmonization with Flow-Based Causal Inference
# 150  Reference-Relation Guided Autoencoder with Dee...
# 159  Federated Semi-supervised Medical Image Classi...
# 160  FedPerl: Semi-supervised Peer Learning for Ski...
# 161  Personalized Retrogress-Resilient Framework fo...
# 162  Federated Whole Prostate Segmentation in MRI w...
# 163  Federated Contrastive Learning for Volumetric ...
# 164  Federated Contrastive Learning for Decentraliz...
# 181                    3  category: classification
# 185                    3  category: classification
# 187                    3  category: classification
# 188                    3  category: classification

# %%
df2012_class
# Out:
#                                                  Title  \
# 4      Surgical Gesture Classification from Video Data
# 7    Efficient Optic Cup Detection from Intra-image...
# 9    Thoracic Abnormality Detection with Data Adapt...
# 10   Domain Transfer Learning for MCI Conversion Pr...
# 12   Incremental Kernel Ridge Regression for the Pr...
# 13   Fuzzy Multi-class Statistical Modeling for Eff...
# 14   Structure and Context in Prostatic Gland Segme...
# 15   Quantitative Characterization of Trabecular Bo...
# 16   Genetic, Structural and Functional Imaging Bio...
# 17   Robust MR Spine Detection Using Hierarchical L...
# 19   A Visual Latent Semantic Approach for Automati...
# 20   Detection of Spontaneous Vesicle Release at In...
# 25   Classification of Ambiguous Nerve Fiber Orient...
# 28   Bi-exponential Magnetic Resonance Signal Model...
# 31   Dictionary Learning and Time Sparsity in Dynam...
# 33   Sparsity-Based Deconvolution of Low-Dose Perfu...
# 36   Oriented Pattern Analysis for Streak Detection...
# 37   Automated Foveola Localization in Retinal 3D-O...
# 38   Intrinsic Melanin and Hemoglobin Colour Compon...
# 40   Apoptosis Detection for Adherent Cell Populati...
# 41      Modeling Dynamic Cellular Morphology in Images
# 42   Learning to Detect Cells Using Non-overlapping...
# 51   Modeling of Multi-View 3D Freehand Radio Frequ...
# 52   Towards Intra-operative PET for Head and Neck ...
# 53   Data-Driven Breast Decompression and Lesion Ma...
# 55   Development of an MRI-Compatible Device for Pr...
# 59   Towards Computer-Assisted Deep Brain Stimulati...
# 61   Combining CRF and Multi-hypothesis Detection f...
# 62                      Hierarchical Manifold Learning
# 82   Localization of Sparse Transmural Excitation S...
# 86   A Novel Sparse Graphical Approach for Multimod...
# 88   Deriving Statistical Significance Maps for SVM...
# 89   Analysis of Longitudinal Shape Variability via...
# 90   Regional Flux Analysis of Longitudinal Atrophy...
# 96   Cardiac Mechanical Parameter Calibration Based...
# 97   Temporal Shape Analysis via the Spectral Signa...
# 103  Uncertainty-Based Feature Learning for Skin Le...
# 105  A Novel Approach for Global Lung Registration ...
# 106  Analytic Regularization of Uniform Cubic B-spl...
# 113  Prediction of Brain MR Scans in Longitudinal T...
# 116  A Feature-Based Developmental Model of the Inf...
# 117  Constrained Sparse Functional Connectivity Net...
# 118  MR-Less Surface-Based Amyloid Estimation by Su...
# 119  Hierarchical Structural Mapping for Globally O...
# 121  Quantitative Evaluation of Statistical Inferen...
# 122  Identifying Sub-Populations via Unsupervised C...
# 123                         Geodesic Information Flows
# 126  Sparse DSI: Learning DSI Structure for Denoisi...
# 128  Estimation of Extracellular Volume from Regula...
# 130  Estimation of Non-negative ODFs Using the Eige...
# 137  Hierarchical Conditional Random Fields for Det...
# 150  Hemodynamic Assessment of Pre- and Post-operat...
# 152  Morphological Analysis of the Left Ventricular...
# 153  Prior-Based Automatic Segmentation of the Caro...
# 154  A Convex Relaxation Approach to Fat/Water Sepa...
# 157  Ultrasound and Fluoroscopic Images Fusion by A...
# 162  Semi-automatic Catheter Reconstruction from Tw...
# 163  Feature Classification for Tracking Articulate...
# 169  Registration Accuracy: How Good Is Good Enough...
# 174  Parametric Dictionary Learning for Modeling EA...
# 177  Multi-scale Characterization of White Matter T...
# 182                Neighbourhood Approximation Forests
# 189  Regional Manifold Learning for Deformable Regi...
# 194  Realistic Head Model Design and 3D Brain Imagi...
# 195  Hemodynamic-Informed Parcellation of fMRI Data...
# 197                    Metamorphic Geodesic Regression
# 202  Tree-Guided Sparse Coding for Brain Disease Cl...
# 203  Improving Accuracy and Power with Transfer Lea...
# 205  Temporally-Constrained Group Sparse Learning f...
# 206  Feature Analysis for Parkinson’s Disease Detec...
# 208  Cortical Folding Analysis on Patients with Alz...
# 213  A Diffusion Model for Detecting and Classifyin...
# 215  Automated Tuberculosis Diagnosis Using Fluores...
# 217  Automatic Location of Vertebrae on DXA Images ...
# 226  Shape Prior Modeling Using Sparse Representati...
# 227  Detection of Substantia Nigra Echogenicities i...
# 228  Prostate Segmentation by Sparse Representation...
# 230  Using Multiparametric Data with Missing Featur...
# 231  Non-local Robust Detection of DTI White Matter...
# 234       Finding Similar 2D X-Ray Coronary Angiograms
# 235  Detection of Vertebral Body Fractures Based on...
# 236  Multiscale Lung Texture Signature Learning Usi...
# 237  Blood Flow Simulation for the Liver after a Vi...
# 239  A Comprehensive Framework for the Detection of...
# 240  Automated Colorectal Cancer Diagnosis for Whol...
# 241  Patient-Adaptive Lesion Metabolism Analysis by...
# 242  A Personalized Biomechanical Model for Respira...
# 243  Endoscope Distortion Correction Does Not (Easi...
# 247  An Invariant Shape Representation Using the An...
# 248  Phase Contrast Image Restoration via Dictionar...
#
#                                                Authors Page numbers  \
# 4       Benjamín Béjar Haro, Luca Zappella, René Vidal        34-41
# 7    Yanwu Xu, Jiang Liu, Stephen Lin, Dong Xu, Car...        58-65
# 9         Yang Song, Weidong Cai, Yun Zhou, Dagan Feng        74-81
# 10             Bo Cheng, Daoqiang Zhang, Dinggang Shen        82-90
# 12   Binbin Pan, James J. Xia, Peng Yuan, Jaime Gat...       99-106
# 13   Jose George, Kathleen Vunckx, Elke Van de Cast...      107-114
# 14           Kien Nguyen, Anindya Sarkar, Anil K. Jain      115-123
# 15                Yinxiao Liu, Punam K. Saha, Ziyue Xu      124-131
# 16   Nikhil Singh, Angela Y. Wang, Preethi Sankaran...      132-140
# 17   Yiqiang Zhan, Dewan Maneesh, Martin Harder, Xi...      141-148
# 19   Angel Cruz-Roa, Fabio González, Joseph Galaro,...      157-164
# 20          Stefan Sokoll, Klaus Tönnies, Martin Heine      165-172
# 25   Melanie Kleiner, Markus Axer, David Gräßel, Ju...      206-213
# 28   Quentin Duché, Oscar Acosta, Giulio Gambarota,...      231-238
# 31   Jose Caballero, Daniel Rueckert, Joseph V. Hajnal      256-263
# 33            Ruogu Fang, Tsuhan Chen, Pina C. Sanelli      272-280
# 36   Maryam Sadeghi, Tim K. Lee, David McLean, Harv...      298-306
# 37   Yu-Ying Liu, Hiroshi Ishikawa, Mei Chen, Gadi ...      307-314
# 38   Ali Madooei, Mark S. Drew, Maryam Sadeghi, M. ...      315-322
# 197  10.1007/978-3-642-33454-2_25               2012.0                    3
# 202  10.1007/978-3-642-33454-2_30               2012.0                    3
# 203  10.1007/978-3-642-33454-2_31               2012.0                    3
# 205  10.1007/978-3-642-33454-2_33               2012.0                    3
# 206  10.1007/978-3-642-33454-2_34               2012.0                    3
# 208  10.1007/978-3-642-33454-2_36               2012.0                    3
# 213  10.1007/978-3-642-33454-2_41               2012.0                    3
# 215  10.1007/978-3-642-33454-2_43               2012.0                    3
# 217  10.1007/978-3-642-33454-2_45               2012.0                    3
# 226  10.1007/978-3-642-33454-2_54               2012.0                    3
# 227  10.1007/978-3-642-33454-2_55               2012.0                    3
# 228  10.1007/978-3-642-33454-2_56               2012.0                    3
# 230  10.1007/978-3-642-33454-2_58               2012.0                    3
# 231  10.1007/978-3-642-33454-2_59               2012.0                    3
# 234  10.1007/978-3-642-33454-2_62               2012.0                    3
# 235  10.1007/978-3-642-33454-2_63               2012.0                    3
# 236  10.1007/978-3-642-33454-2_64               2012.0                    3
# 237  10.1007/978-3-642-33454-2_65               2012.0                    3
# 239  10.1007/978-3-642-33454-2_67               2012.0                    3
# 240  10.1007/978-3-642-33454-2_68               2012.0                    3
# 241  10.1007/978-3-642-33454-2_69               2012.0                    3
# 242  10.1007/978-3-642-33454-2_70               2012.0                    3
# 243  10.1007/978-3-642-33454-2_71               2012.0                    3
# 247  10.1007/978-3-642-33454-2_75               2012.0                    3
# 248  10.1007/978-3-642-33454-2_76               2012.0                    3
#
#                      category
# 4    category: classification
# 7    category: classification
# 9    category: classification
# 10   category: classification
# 12   category: classification
# 13   category: classification
# 14   category: classification
# 15   category: classification
# 16   category: classification
# 17   category: classification
# 19   category: classification
# 20   category: classification
# 25   category: classification
# 28   category: classification
# 31   category: classification
# 33   category: classification
# 36   category: classification
# 37   category: classification
# 38   category: classification
# 40   category: classification
# 41   category: classification
# 42   category: classification
# 51   category: classification
# 52   category: classification
# 53   category: classification
# 55   category: classification
# 59   category: classification
# 61   category: classification
# 62   category: classification
# 82   category: classification
# 86   category: classification
# 88   category: classification
# 89   category: classification
# 90   category: classification
# 96   category: classification
# 97   category: classification
# 103  category: classification
# 105  category: classification
# 106  category: classification
# 113  category: classification
# 116  category: classification
# 117  category: classification
# 118  category: classification
# 119  category: classification
# 121  category: classification
# 122  category: classification
# 123  category: classification
# 126  category: classification
# 128  category: classification
# 130  category: classification
# 137  category: classification
# 150  category: classification
# 152  category: classification
# 153  category: classification
# 154  category: classification
# 157  category: classification
# 162  category: classification
# 163  category: classification
# 169  category: classification
# 174  category: classification
# 177  category: classification
# 182  category: classification
# 189  category: classification
# 194  category: classification
# 195  category: classification
# 197  category: classification
# 202  category: classification
# 203  category: classification
# 205  category: classification
# 206  category: classification
# 208  category: classification
# 213  category: classification
# 215  category: classification
# 217  category: classification
# 226  category: classification
# 227  category: classification
# 228  category: classification
# 230  category: classification
# 231  category: classification
# 234  category: classification
# 235  category: classification
# 236  category: classification
# 237  category: classification
# 239  category: classification
# 240  category: classification
# 241  category: classification
# 242  category: classification
# 243  category: classification
# 247  category: classification
# 248  category: classification
