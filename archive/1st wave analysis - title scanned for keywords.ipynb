# %%
import pandas as pd

# %%
#reading in the files

df_2012 = pd.read_csv(r'C:\Users\chris\Desktop\Value-Analysis-Thesis\mining inital data\database_miccai_2012.csv')
df_2021 = pd.read_csv(r'C:\Users\chris\Desktop\Value-Analysis-Thesis\mining inital data\database_miccai_2021.csv')

# %%
df_2012
# Out:
#      Unnamed: 0                                              Title  \
# 0             0  Reliable Assessment of Perfusivity and Diffusi...
# 1             1  Multi-organ Abdominal CT Segmentation Using Hi...
# 2             2  Radiation-Free Drill Guidance in Interlocking ...
# 3             3  Developing Essential Rigid-Flexible Outer Shea...
# 4             4    Surgical Gesture Classification from Video Data
# ..          ...                                                ...
# 247         248  An Invariant Shape Representation Using the An...
# 248         249  Phase Contrast Image Restoration via Dictionar...
# 249         250  Context-Constrained Multiple Instance Learning...
# 250         251  Structural-Flow Trajectories for Unravelling 3...
# 251         252  Online Blind Calibration of Non-uniform Photod...
#
#                                                Authors Page numbers  \
# 0    M. Freiman, S. D. Voss, R. V. Mulkern, J. M. P...          1-9
# 1    Robin Wolz, Chengwen Chu, Kazunari Misawa, Ken...        10-17
# 2    Benoit Diotte, Pascal Fallavollita, Lejing Wan...        18-25
# 3    Siyang Zuo, Takeshi Ohdaira, Kenta Kuwana, Yos...        26-33
# 4       Benjamín Béjar Haro, Luca Zappella, René Vidal        34-41
# ..                                                 ...          ...
# 247  A. A. Joshi, S. Ashrafulla, D. W. Shattuck, H....      607-614
# 248  Hang Su, Zhaozheng Yin, Takeo Kanade, Seungil Huh      615-622
# 249  Yan Xu, Jianwen Zhang, Eric I-Chao Chang, Maod...      623-630
# 250  Katerina Fragkiadaki, Weiyu Zhang, Jianbo Shi,...      631-638
# 251    Nicolas Savoire, Barbara André, Tom Vercauteren      639-646
#
#                                        DOI  Year of publication  \
# 0     /chapter/10.1007/978-3-642-33415-3_1               2012.0
# 1     /chapter/10.1007/978-3-642-33415-3_2               2012.0
# 2     /chapter/10.1007/978-3-642-33415-3_3               2012.0
# 3     /chapter/10.1007/978-3-642-33415-3_4               2012.0
# 4     /chapter/10.1007/978-3-642-33415-3_5               2012.0
# ..                                     ...                  ...
# 247  /chapter/10.1007/978-3-642-33454-2_75               2012.0
# 248  /chapter/10.1007/978-3-642-33454-2_76               2012.0
# 249  /chapter/10.1007/978-3-642-33454-2_77               2012.0
# 250  /chapter/10.1007/978-3-642-33454-2_78               2012.0
# 251  /chapter/10.1007/978-3-642-33454-2_79               2012.0
#
#      Part of publication
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ..                   ...
# 247                    3
# 248                    3
# 249                    3
# 250                    3
# 251                    3
#
# [252 rows x 7 columns]

# %%
#removing unnecessary index column
df_2012 = df_2012.drop("Unnamed: 0", axis = 1)
df_2021 = df_2021.drop("Unnamed: 0", axis = 1)

# %%
#dropping erratum article from 2012
df_2012.drop(df_2012[df_2012["Title"].str.contains("Erratum")].index, inplace = True)
df_2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 252 entries, 0 to 251
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           252 non-null    int64
#  1   Title                252 non-null    object
#  2   Authors              252 non-null    object
#  3   Page numbers         252 non-null    object
#  4   DOI                  252 non-null    object
#  5   Year of publication  252 non-null    float64
#  6   Part of publication  252 non-null    int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 15.8+ KB

# %%
#dropping corrections to articles from 2021 - still one more article found than according to 
#description on Springer!

df_2021.drop(df_2021[df_2021["Title"].str.contains("Correction to")].index, inplace=True)
df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 531 entries, 0 to 530
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                531 non-null    object
#  1   Authors              531 non-null    object
#  2   Page numbers         531 non-null    object
#  3   DOI                  531 non-null    object
#  4   Year of publication  531 non-null    int64
#  5   Part of publication  531 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 29.0+ KB

# %%
#fixing two found errors with wierd strings in titles
#df_2021.loc[167]
wrong_title = df_2021.at[167, 'Title']
start = wrong_title[0:wrong_title.find("$")-1]
end = wrong_title[wrong_title.find("$")+13:]

right_title = start + end
right_title

df_2021['Title'] = df_2021['Title'].replace([wrong_title], right_title)
df_2021.at[167, 'Title']
# Out:
# 'Fairness in Cardiac MR Image Analysis: An Investigation of Bias Due to Data Imbalance in Deep Learning Based SegmentatiCardiac MR Image Analysis: An Investigation of Bias Due to Data Imbalance in Deep Learning Based Segmentation'

# %%
#df_2021.loc[329]
wrong_title = df_2021.at[329, 'Title']

right_title = wrong_title[(wrong_title.find("Auditing")):]


df_2021['Title'] = df_2021['Title'].replace([wrong_title], right_title)
df_2021.at[329, 'Title']
# Out:
# 'y'

# %%
#looks at the titles and checks if the word classification, prediction or detection are present
#creates a list of 0's and 1's accordingly

#need to rework this completely! 
def title_analysis(df, keywords):
    class_list = []
    for index in df['Title']:
        word_list = []
        for word in keywords:
            if index.lower().find(word) > 0:
                word_list.append(1)
            else:
                word_list.append(0)
        if 1 in word_list:
            class_list.append(1)
        else: class_list.append(0)
    
    #going back over the list and checking for segmentation + prediction/detection and changing to a 0 if so
    #should also change this??
    i = 0
    for index in df['Title']:
        if index.lower().find("segmentation") > 0 and index.lower().find("prediction") > 0:
            class_list[i] = 0
        elif index.lower().find("segmentation") > 0 and index.lower().find("detection") > 0:
            class_list[i] = 0
        i = i+1
    
    df['Keywords in title'] = class_list
    
    return df

# %%
#calls method for inital title analysis and adds list to the dataframe
keywords= ['classification', 'prediction', 'detection']

df_2012= title_analysis(df_2012, keywords)

# %%
#apparently this found 32 articles
df_2012[df_2012['Keywords in title'] == 1].count()
# Out:
# Unnamed: 0             32
# Title                  32
# Authors                32
# Page numbers           32
# DOI                    32
# Year of publication    32
# Part of publication    32
# Keywords in title      32
# dtype: int64

# %%
old = df_2012[df_2012['Keywords in title'] == 1]

# %%
df = pd.read_csv(r"C:\Users\chris\Desktop\Value-Analysis-Thesis\analysis\annotations_data.csv")

# %%
cat = df[df['Which year is the article from?']== 2012]

# %%
cattrue = cat[cat['Is the article accurately labelled as classification?'] == 'Yes']
catfalse = cat[cat['Is the article accurately labelled as classification?'] == 'No']

# %%
print(len(cat), " ",len(cattrue), " ", len(catfalse))
print((38/85) ," " ,(47/85))
# Out:
# 85   38   47
# 0.4470588235294118   0.5529411764705883

# %%
cattrue = cat[cat['Is the article accurately labelled as classification?'] == 'Yes']
cattrue = cattrue.reset_index()

# %%
new_list = list(cattrue["What is the article's index?"])

# %%
old_list = list(old['index'])

# %%
plus_abstract = []
for element in new_list:
    if element not in old_list:
        plus_abstract.append(element)

# %%
title_only = []
for element in old_list:
    if element not in new_list:
        title_only.append(element)

# %%
len(plus_abstract)
# Out:
# 21

# %%
len(title_only)
#as title_only found 32 results this is almost half that are not the same as in new method. 
#so that is interesting
# Out:
# 15

# %%
df_2012[df_2012['Keywords in title'] == 1]
# Out:
#                                                  Title  \
# 4      Surgical Gesture Classification from Video Data
# 7    Efficient Optic Cup Detection from Intra-image...
# 9    Thoracic Abnormality Detection with Data Adapt...
# 10   Domain Transfer Learning for MCI Conversion Pr...
# 12   Incremental Kernel Ridge Regression for the Pr...
# 14   Structure and Context in Prostatic Gland Segme...
# 16   Genetic, Structural and Functional Imaging Bio...
# 17   Robust MR Spine Detection Using Hierarchical L...
# 36   Oriented Pattern Analysis for Streak Detection...
# 37   Automated Foveola Localization in Retinal 3D-O...
# 38   Intrinsic Melanin and Hemoglobin Colour Compon...
# 40   Apoptosis Detection for Adherent Cell Populati...
# 74   Automatic Detection and Classification of Teet...
# 76   Frangi Goes US : Multiscale Tubular Structure ...
# 88   Deriving Statistical Significance Maps for SVM...
# 117  Constrained Sparse Functional Connectivity Net...
# 134  Closed-Form Relaxation for MRF-MAP Tissue Clas...
# 137  Hierarchical Conditional Random Fields for Det...
# 155  Regional Heart Motion Abnormality Detection vi...
# 157  Ultrasound and Fluoroscopic Images Fusion by A...
# 163  Feature Classification for Tracking Articulate...
# 195  Hemodynamic-Informed Parcellation of fMRI Data...
# 198  Eigenanatomy Improves Detection Power for Long...
# 202  Tree-Guided Sparse Coding for Brain Disease Cl...
# 206  Feature Analysis for Parkinson’s Disease Detec...
# 221  Anatomical Landmark Detection Using Nearest Ne...
# 222  Integration of Local and Global Features for A...
# 228  Prostate Segmentation by Sparse Representation...
# 231  Non-local Robust Detection of DTI White Matter...
# 239  A Comprehensive Framework for the Detection of...
# 242  A Personalized Biomechanical Model for Respira...
# 243  Endoscope Distortion Correction Does Not (Easi...
#
#                                                Authors Page numbers  \
# 4       Benjamín Béjar Haro, Luca Zappella, René Vidal        34-41
# 7    Yanwu Xu, Jiang Liu, Stephen Lin, Dong Xu, Car...        58-65
# 9         Yang Song, Weidong Cai, Yun Zhou, Dagan Feng        74-81
# 10             Bo Cheng, Daoqiang Zhang, Dinggang Shen        82-90
# 12   Binbin Pan, James J. Xia, Peng Yuan, Jaime Gat...       99-106
# 14           Kien Nguyen, Anindya Sarkar, Anil K. Jain      115-123
# 16   Nikhil Singh, Angela Y. Wang, Preethi Sankaran...      132-140
# 17   Yiqiang Zhan, Dewan Maneesh, Martin Harder, Xi...      141-148
# 36   Maryam Sadeghi, Tim K. Lee, David McLean, Harv...      298-306
# 37   Yu-Ying Liu, Hiroshi Ishikawa, Mei Chen, Gadi ...      307-314
# 38   Ali Madooei, Mark S. Drew, Maryam Sadeghi, M. ...      315-322
# 40   Seungil Huh, Dai Fei Elmer Ker, Hang Su, Takeo...      331-339
# 74   Nguyen The Duy, Hans Lamecker, Dagmar Kainmuel...      609-616
# 76    Paulo Waelkens, Seyed-Ahmad Ahmadi, Nassir Navab      625-633
# 88                 Bilwaj Gaonkar, Christos Davatzikos      723-730
# 117  Chong-Yaw Wee, Pew-Thian Yap, Daoqiang Zhang, ...      212-219
# 134                                       Alexis Roche      355-362
# 137  Zahra Karimaghaloo, Douglas L. Arnold, D. Loui...      379-386
# 155  Kumaradevan Punithakumar, Ismail Ben Ayed, Ali...      527-534
# 157  Peter Mountney, Razvan Ionasec, Markus Kaizer,...      544-551
# 163            Austin Reiter, Peter K. Allen, Tao Zhao      592-600
# 195        L. Chaari, F. Forbes, T. Vincent, P. Ciuciu      180-188
# 198  Brian Avants, Paramveer Dhillon, Benjamin M. K...      206-213
# 202  Manhua Liu, Daoqiang Zhang, Pew-Thian Yap, Din...      239-247
# 206           Lei Chen, Johann Hagenah, Alfred Mertins      272-279
# 221                           David Liu, S. Kevin Zhou      393-401
# 222  Bahbibi Rahmatullah, Aris T. Papageorghiou, J....      402-409
# 228               Yaozong Gao, Shu Liao, Dinggang Shen      451-458
# 231                   Olivier Commowick, Aymeric Stamm      476-484
# 239  Camille Maumet, Pierre Maurel, Jean-Christophe...      542-549
# 242  B. Fuerst, T. Mansi, Jianwen Zhang, P. Khurd, ...      566-573
# 243  Jutta Hämmerle-Uhl, Yvonne Höller, Andreas Uhl...      574-581
#
#                                        DOI  Year of publication  \
# 4     /chapter/10.1007/978-3-642-33415-3_5               2012.0
# 7     /chapter/10.1007/978-3-642-33415-3_8               2012.0
# 9    /chapter/10.1007/978-3-642-33415-3_10               2012.0
# 10   /chapter/10.1007/978-3-642-33415-3_11               2012.0
# 12   /chapter/10.1007/978-3-642-33415-3_13               2012.0
# 14   /chapter/10.1007/978-3-642-33415-3_15               2012.0
# 16   /chapter/10.1007/978-3-642-33415-3_17               2012.0
# 17   /chapter/10.1007/978-3-642-33415-3_18               2012.0
# 36   /chapter/10.1007/978-3-642-33415-3_37               2012.0
# 37   /chapter/10.1007/978-3-642-33415-3_38               2012.0
# 38   /chapter/10.1007/978-3-642-33415-3_39               2012.0
# 40   /chapter/10.1007/978-3-642-33415-3_41               2012.0
# 74   /chapter/10.1007/978-3-642-33415-3_75               2012.0
# 76   /chapter/10.1007/978-3-642-33415-3_77               2012.0
# 88   /chapter/10.1007/978-3-642-33415-3_89               2012.0
# 117  /chapter/10.1007/978-3-642-33418-4_27               2012.0
# 134  /chapter/10.1007/978-3-642-33418-4_44               2012.0
# 137  /chapter/10.1007/978-3-642-33418-4_47               2012.0
# 155  /chapter/10.1007/978-3-642-33418-4_65               2012.0
# 157  /chapter/10.1007/978-3-642-33418-4_67               2012.0
# 163  /chapter/10.1007/978-3-642-33418-4_73               2012.0
# 195  /chapter/10.1007/978-3-642-33454-2_23               2012.0
# 198  /chapter/10.1007/978-3-642-33454-2_26               2012.0
# 202  /chapter/10.1007/978-3-642-33454-2_30               2012.0
# 206  /chapter/10.1007/978-3-642-33454-2_34               2012.0
# 221  /chapter/10.1007/978-3-642-33454-2_49               2012.0
# 222  /chapter/10.1007/978-3-642-33454-2_50               2012.0
# 228  /chapter/10.1007/978-3-642-33454-2_56               2012.0
# 231  /chapter/10.1007/978-3-642-33454-2_59               2012.0
# 239  /chapter/10.1007/978-3-642-33454-2_67               2012.0
# 242  /chapter/10.1007/978-3-642-33454-2_70               2012.0
# 243  /chapter/10.1007/978-3-642-33454-2_71               2012.0
#
#      Part of publication  Keywords in title
# 4                      1                  1
# 7                      1                  1
# 9                      1                  1
# 10                     1                  1
# 12                     1                  1
# 14                     1                  1
# 16                     1                  1
# 17                     1                  1
# 36                     1                  1
# 37                     1                  1
# 38                     1                  1
# 40                     1                  1
# 74                     1                  1
# 76                     1                  1
# 88                     1                  1
# 117                    2                  1
# 134                    2                  1
# 137                    2                  1
# 155                    2                  1
# 157                    2                  1
# 163                    2                  1
# 195                    3                  1
# 198                    3                  1
# 202                    3                  1
# 206                    3                  1
# 221                    3                  1
# 222                    3                  1
# 228                    3                  1
# 231                    3                  1
# 239                    3                  1
# 242                    3                  1
# 243                    3                  1

# %%
#now replicating for 2021

classification_list = titleAnalysis(df_2021)

df_2021['Keywords in title'] = classification_list

# %%
#found 100 articles in 2021
df_2021[df_2021['Keywords in title'] == 1].count()
# Out:
# Unnamed: 0             100
# Title                  100
# Authors                100
# Page numbers           100
# DOI                    100
# Year of publication    100
# Keywords in title      100
# dtype: int64

# %%
#this should probably output an edited csv for next section to work on!
df_2012.to_csv("database_miccai_2012_first_wave.csv")
df_2021.to_csv("database_miccai_2021_first_wave.csv")
